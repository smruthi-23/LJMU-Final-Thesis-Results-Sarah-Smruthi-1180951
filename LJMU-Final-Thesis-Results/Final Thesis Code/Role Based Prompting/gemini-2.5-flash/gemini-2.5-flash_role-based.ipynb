# %%
# !pip install google-generativeai rouge-score bert-score nltk
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.28.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.187.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (2.11.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rouge-score) (2.0.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.8.0+cu126)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.2.2)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from bert-score) (4.57.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from bert-score) (2.32.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score) (3.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bert-score) (25.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core->google-generativeai) (1.72.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->bert-score) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->bert-score) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->bert-score) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.36.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (6.0.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=3.0.0->bert-score) (0.6.2)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.31.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (0.2.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score) (3.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert-score) (1.2.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->bert-score) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->bert-score) (3.0.3)
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.1 MB/s eta 0:00:00
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24934 sha256=17c41b68acc7a96849ff64caf44e458fe1d85345980457c674bb31dc8a2af89f
#   Stored in directory: /root/.cache/pip/wheels/85/9d/af/01feefbe7d55ef5468796f0c68225b6788e85d9d0a281e7a70
# Successfully built rouge-score
# Installing collected packages: rouge-score, bert-score
# Successfully installed bert-score-0.3.13 rouge-score-0.1.2
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# %%javascript
# function ClickConnect(){
#   console.log("Clicking");
#   document.querySelector("colab-toolbar-button#connect").click();
# }
# setInterval(ClickConnect, 60000)

# %%
#####################################################################
# 1. MOUNT DRIVE & IMPORTS
#####################################################################
from google.colab import drive
drive.mount('/content/drive')

import os, re, json, time, logging
from datetime import datetime
from pathlib import Path
from typing import List, Dict, Any

import pandas as pd
import numpy as np
import google.generativeai as genai


#####################################################################
# 2. PATHS & API KEY
#####################################################################
INPUT_FILE = "/content/drive/MyDrive/Final Thesis Code/Input/clean_input_30.xlsx"

BASE_OUT = Path("/content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/")
BASE_OUT.mkdir(parents=True, exist_ok=True)

FINAL_OUTPUT_FILE = BASE_OUT / "gemini-2.5-flash_role_full_output.xlsx"

API_KEY_PATH = "/content/drive/MyDrive/Final Thesis Code/api_keys/gemini_key4.txt"

def load_key(path: str) -> str:
    with open(path, "r") as f:
        return f.read().strip()

API_KEY = load_key(API_KEY_PATH)
os.environ["GOOGLE_API_KEY"] = API_KEY
genai.configure(api_key=API_KEY)

print("Input file:", INPUT_FILE)
print("Output folder:", BASE_OUT)
print("Gemini key loaded ✓")


#####################################################################
# 3. GLOBAL CONFIG
#####################################################################
MODEL_NAME     = "gemini-2.5-flash"
MAX_CHARS      = 2600
GLOBAL_MIN_GAP = 70       # seconds between calls (soft global wait)
LAST_TS        = 0.0

VALID_TOPICS = [
    "Natural Language Processing","Artificial Intelligence","Prompt Engineering",
    "Machine Learning","Deep Learning","Reinforcement Learning","Generative AI",
    "Data Science","Time Series","Statistics","LangChain","Langraph",
    "Python Programming","Mlops","Agentic AI","Other"
]


#####################################################################
# 4. LOGGING
#####################################################################
def setup_logging():
    logs = Path("/content/logs")
    logs.mkdir(exist_ok=True)
    logfile = logs / f"log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"

    logging.basicConfig(
        level=logging.INFO,
        handlers=[
            logging.FileHandler(logfile, encoding="utf-8"),
            logging.StreamHandler()
        ],
        format="%(asctime)s | %(levelname)s | %(message)s",
    )
    return logging.getLogger(__name__)

logger = setup_logging()


#####################################################################
# 5. CLEANING, SANITISE & CHUNKING
#####################################################################
def deep_clean(text: str) -> str:
    t = str(text)
    t = re.sub(r'https?://\S+|www\.\S+', ' ', t)
    t = re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b', ' ', t)
    t = re.sub(r'\[.*?\]|\(.*?\)', ' ', t)
    t = re.sub(r'\s+', ' ', t)
    # acronym expansion
    t = re.sub(r'\bNLP\b', 'Natural Language Processing (NLP)', t)
    t = re.sub(r'\bML\b', 'Machine Learning (ML)', t)
    t = re.sub(r'\bAI\b', 'Artificial Intelligence (AI)', t)
    return t.strip()

def sanitize(text: str) -> str:
    """Light sanitisation for prompts (keeps content, flattens whitespace)."""
    return re.sub(r'\s+', ' ', str(text)).strip()

def chunk_text(text: str, max_chars: int = MAX_CHARS) -> List[str]:
    clean = deep_clean(text)
    if len(clean) <= max_chars:
        return [clean] if clean else [""]
    sents = [s.strip() for s in re.split(r'(?<=[.!?])\s+', clean) if s.strip()]
    chunks, cur = [], ""
    for s in sents:
        if len(cur) + len(s) + 1 <= max_chars:
            cur = (cur + " " + s).strip()
        else:
            if cur:
                chunks.append(cur)
            cur = s
    if cur:
        chunks.append(cur)
    return chunks or [""]


#####################################################################
# 6. JSON EXTRACTION
#####################################################################
def extract_json(text: str) -> Dict[str, Any]:
    """Extract outermost {...} and parse as JSON."""
    if not text:
        return {}
    start = text.find("{")
    end = text.rfind("}")
    if start == -1 or end == -1 or end <= start:
        return {}
    candidate = text[start:end+1]
    try:
        return json.loads(candidate)
    except Exception:
        return {}


#####################################################################
# 7. GEMINI CALL WITH GLOBAL WAIT
#####################################################################
def gemini_call(prompt: str, temperature: float = 0.2, retries: int = 3) -> str:
    global LAST_TS
    now = time.time()

    # soft global rate limiting
    if LAST_TS > 0 and now - LAST_TS < GLOBAL_MIN_GAP:
        wait = GLOBAL_MIN_GAP - (now - LAST_TS)
        logger.info(f"Waiting {wait:.1f}s (respecting global gap)")
        time.sleep(wait)

    model = genai.GenerativeModel(MODEL_NAME)
    cfg = {"temperature": temperature}

    for attempt in range(1, retries+1):
        try:
            resp = model.generate_content(prompt, generation_config=cfg)
            LAST_TS = time.time()
            return (getattr(resp, "text", "") or "").strip()
        except Exception as e:
            logger.warning(f"Gemini call failed ({attempt}/{retries}): {e}")
            time.sleep(4 * attempt)

    logger.error("Gemini failed after all retries — returning empty string.")
    return ""


#####################################################################
# 8. ROLE-BASED TASK BASE CLASS
#####################################################################
class GeminiRoleTask:
    """Thin wrapper that reuses gemini_call + global wait."""
    def __init__(self, temperature: float = 0.2):
        self.temperature = temperature

    def _run(self, prompt: str) -> str:
        return gemini_call(prompt, temperature=self.temperature)


#####################################################################
# 9. ROLE-BASED TASK CLASSES
#####################################################################

class SummarisationRole(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        t = sanitize(t)
        return f"""
You are an **Educational Content Summariser** working for a university’s online learning platform.

Your role:
- Summarise lectures and AI/ML transcripts into concise, academic English.
- Highlight only key insights, definitions, examples, and outcomes.

Guidelines:
- Write 120–150 words (5–6 sentences).
- Avoid filler phrases like “the video discusses”.
- Use direct, objective tone suitable for academic notes.
- End with one line capturing the overall insight.

Return JSON only:
{{"generated_summary": "<summary text>"}}

Transcript :
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> str:
        txt = self._run(self.build_prompt(t))
        if not txt:
            return "ERROR"
        try:
            return json.loads(txt).get("generated_summary", "").strip()
        except Exception:
            s, e = txt.find("{"), txt.rfind("}")
            if s != -1 and e != -1:
                try:
                    return json.loads(txt[s:e+1]).get("generated_summary", "").strip()
                except Exception:
                    pass
        return txt.strip()[:2000]


class TopicRoleMulti(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        topics = ", ".join(VALID_TOPICS)
        t = sanitize(t)
        return f"""
You are a **Research Domain Classifier** for AI and ML educational transcripts.

Role Description:
You are an academic expert responsible for categorising transcripts into precise research areas based on terminology, algorithms, or learning paradigms mentioned.

Decision Guidelines:
- Identify the technical scope and key methods discussed.
- Select up to THREE relevant topics from the list below.
- Prefer domain-specific categories (e.g., "Reinforcement Learning") over broad ones (e.g., "Machine Learning").
- Avoid guessing: only include topics clearly supported by evidence in the text.

AVAILABLE TOPICS:
{topics}

Output Format:
Return valid one-line JSON only:
{{"predicted_topics":["<TOPIC1>","<TOPIC2>",...]}}

Transcript:
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> List[str]:
        raw = self._run(self.build_prompt(t))
        if not raw:
            return ["Other"]
        try:
            obj = json.loads(raw)
            tp = obj.get("predicted_topics", [])
            if isinstance(tp, str):
                tp = [tp]
        except Exception:
            tp = [v for v in VALID_TOPICS if v.lower() in raw.lower()]
        tp = [x for x in tp if x in VALID_TOPICS]
        return tp or ["Other"]


class QARole(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        t = sanitize(t)
        return f"""
You are an **Academic Question Author** who designs comprehension questions from lecture transcripts.

Role Objectives:
- Draft 5 short-answer questions to test conceptual understanding.
- Use “What, Why, How, When, Who” formats.
- Each answer must come verbatim or closely from transcript phrases (≤25 words).

Return JSON only:
{{"generated_questions":[{{"q":"...","a":"..."}},...]}}

Transcript :
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> List[Dict[str, str]]:
        txt = self._run(self.build_prompt(t))
        if not txt:
            return []
        try:
            return json.loads(txt).get("generated_questions", [])
        except Exception:
            s, e = txt.find("{"), txt.rfind("}")
            if s != -1 and e != -1:
                try:
                    return json.loads(txt[s:e+1]).get("generated_questions", [])
                except Exception:
                    pass
        return []


class ConceptRole(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        t = sanitize(t)
        return f"""
You are an **AI Glossary Curator** creating concise glossaries for students.

Your Role:
- Extract exactly 10–12 distinct key technical terms, tools, or concepts.
- Focus on ML, NLP, Agentic AI, and related domain-specific nouns.
- Remove words like “video”, “lesson”, “concept”, “people”.

Return JSON only:
{{"key_concepts":["concept1","concept2",...]}}

Transcript :
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> List[str]:
        txt = self._run(self.build_prompt(t))
        if not txt:
            return []
        try:
            return json.loads(txt).get("key_concepts", [])
        except Exception:
            s, e = txt.find("{"), txt.rfind("}")
            if s != -1 and e != -1:
                try:
                    return json.loads(txt[s:e+1]).get("key_concepts", [])
                except Exception:
                    pass
        return []


#####################################################################
# 10. ROLE-BASED TASK WRAPPERS (MATCH OLD FUNCTION SIGNATURES)
#####################################################################

# 10.1 ROLE-BASED SUMMARISATION (still hierarchical: per-chunk + final combine)
def generate_summary(transcript: str) -> str:
    chunks = chunk_text(transcript)
    partial_summaries: List[str] = []

    summariser = SummarisationRole(temperature=0.18)

    for i, c in enumerate(chunks, start=1):
        logger.info(f"Summarisation (role-based) – chunk {i}/{len(chunks)}")
        chunk_summary = summariser.run(c)
        if not chunk_summary:
            chunk_summary = ""
        partial_summaries.append(chunk_summary)

    combined = " ".join(p for p in partial_summaries if p)

    # Final combine using a simple JSON instruction (kept same style)
    final_prompt = f"""
Combine the following draft summaries into ONE coherent summary.

Requirements:
- Length: 120–160 words.
- Academic tone.
- Preserve main technical ideas and conclusions.
- No bullet points, no headings, no reasoning.

Return ONLY JSON:
{{"generated_summary":"<summary text>"}}

Draft Summaries:
\"\"\"{combined}\"\"\""""

    out2 = gemini_call(final_prompt, temperature=0.18)
    j2 = extract_json(out2)
    final_summary = j2.get("generated_summary", "").strip()
    if not final_summary:
        final_summary = out2.strip()[:900]
    return final_summary


# 10.2 ROLE-BASED TOPIC CLASSIFICATION (multi-label)
def classify_topic(transcript: str, summary: str) -> List[str]:
    # Use first chunk to keep tokens bounded (same as before)
    first_chunk = chunk_text(transcript)[0]
    classifier = TopicRoleMulti(temperature=0.22)
    topics = classifier.run(first_chunk)

    # Normalise + max 3 + fallback already handled in TopicRoleMulti
    cleaned: List[str] = []
    for t in topics:
        t = str(t).strip()
        for v in VALID_TOPICS:
            if t.lower() == v.lower():
                cleaned.append(v)
                break
    cleaned = list(dict.fromkeys(cleaned))[:3]
    return cleaned or ["Other"]


# 10.3 ROLE-BASED Q&A GENERATION
def generate_qa(transcript: str) -> str:
    first_chunk = chunk_text(transcript)[0]
    qa_task = QARole(temperature=0.15)
    qas = qa_task.run(first_chunk)

    lines: List[str] = []
    if isinstance(qas, list):
        for qa in qas:
            q = str(qa.get("q", "")).strip()
            a = str(qa.get("a", "")).strip()
            if q:
                lines.append(f"Q: {q}")
            if a:
                lines.append(f"A: {a}")
    return "\n".join(lines).strip()


# 10.4 ROLE-BASED KEY CONCEPT EXTRACTION
def generate_concepts(transcript: str) -> str:
    first_chunk = chunk_text(transcript)[0]
    concept_task = ConceptRole(temperature=0.22)
    concepts = concept_task.run(first_chunk)

    cleaned: List[str] = []
    if isinstance(concepts, list):
        for c in concepts:
            c2 = str(c).strip()
            if c2:
                cleaned.append(c2)
    return ", ".join(cleaned)


#####################################################################
# 11. MAIN PIPELINE — GENERATION ONLY (NO EVALUATION)
#####################################################################
def run_pipeline() -> pd.DataFrame:
    df = pd.read_excel(INPUT_FILE)
    results: List[Dict[str, Any]] = []

    if FINAL_OUTPUT_FILE.exists():
        old = pd.read_excel(FINAL_OUTPUT_FILE)
        if "row_index" in old.columns:
            done = set(old["row_index"])
            results = old.to_dict(orient="records")
            print(f"Resuming: {len(done)} rows already processed.")
        else:
            done = set()
    else:
        done = set()

    for idx, row in df.iterrows():
        if idx in done:
            print(f"Skipping row {idx} (already done)")
            continue

        title = str(row.get("title", "")).strip()
        transcript = str(row.get("transcript", "")).strip()

        print("\n" + "="*80)
        print(f"PROCESSING ROW {idx}: {title}")
        print("="*80)

        try:
            summary  = generate_summary(transcript)
            topics   = classify_topic(transcript, summary)
            qa_text  = generate_qa(transcript)
            concepts = generate_concepts(transcript)
        except Exception as e:
            logger.error(f"Error row {idx}: {e}")
            summary, topics, qa_text, concepts = "", ["Other"], "", ""

        print("\nSUMMARY:\n", summary)
        print("\nTOPICS:\n", topics)
        print("\nQ&A:\n", qa_text)
        print("\nKEY CONCEPTS:\n", concepts)

        rec = {
            "row_index": idx,
            "title": title,
            "summary": summary,
            "topic_classification": ", ".join(topics),
            "Q_and_A": qa_text,
            "key_concepts": concepts
        }
        results.append(rec)

        pd.DataFrame(results).to_excel(FINAL_OUTPUT_FILE, index=False)
        print(f"Saved row {idx} → {FINAL_OUTPUT_FILE}")

    df_out = pd.DataFrame(results)
    df_out.to_excel(FINAL_OUTPUT_FILE, index=False)
    print("\nDONE. Final file saved:", FINAL_OUTPUT_FILE)
    return df_out


#####################################################################
# 12. RUN GENERATION ONLY
#####################################################################
df_out = run_pipeline()
print("\nRole-based generation pipeline completed (NO evaluation).")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Input file: /content/drive/MyDrive/Final Thesis Code/Input/clean_input_30.xlsx
# Output folder: /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash
# Gemini key loaded ✓
#
# ================================================================================
# PROCESSING ROW 0: Reinforcement Learning through Human Feedback - EXPLAINED! | RLHF
# ================================================================================
#
# SUMMARY:
#  Reinforcement Learning with Human Feedback (RLHF) integrates human input to guide and accelerate the training of reinforcement learning algorithms, fostering faster learning and the generation of human-preferred responses. Practically, RLHF is instrumental in fine-tuning large language models such as ChatGPT. The process involves initially training a reward model, often a GPT architecture, to assess and score response quality based on human rankings. This reward model, combined with algorithms like Proximal Policy Optimization (PPO), then iteratively refines the language model's response generation by utilizing the reward model's score within the loss function for network updates. This iterative training significantly enhances the model's ability to generate high-quality, human-aligned responses, underscoring RLHF's crucial role in developing AI systems aligned with human preferences.
#
# TOPICS:
#  ['Reinforcement Learning', 'Generative AI', 'Deep Learning']
#
# Q&A:
#  Q: What is reinforcement learning through human feedback (RLHF)?
# A: RLHF is a framework that integrates human feedback into the training process of a reinforcement learning algorithm.
# Q: How does human feedback help Frank in the grid world scenario?
# A: Human feedback allows Frank to learn faster and to give responses that are more human favored.
# Q: Why is a reward model trained in the process of fine-tuning ChatGPT with human feedback?
# A: The reward model assesses and scores the quality of answers generated by ChatGPT, indicating how good an answer is to a question.
# Q: When can humans provide feedback to a reinforcement learning algorithm like Frank?
# A: Humans can provide feedback as a mentor while the reinforcement learning algorithm is learning.
# Q: Who ranks the responses to train the reward model for ChatGPT?
# A: We as humans take the responses and rank them based on which was the best response versus the worst response.
#
# KEY CONCEPTS:
#  Reinforcement Learning, Human Feedback, Grid World, Reward, Reinforcement Learning Algorithm, Q-learning, DQ learning, Proximal Policy Optimization, Reward Model, GPT Architecture, Fine-tune, Backpropagation
# Saved row 0 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 1: Soft Margin SVM and Kernels with CVXOPT - Practical Machine Learning Tutorial with Python p.32
# ================================================================================
#
# SUMMARY:
#  This tutorial comprehensively examines kernel methods in Support Vector Machines (SVMs) for handling nonlinear data, focusing on their theoretical underpinnings and practical visualization. Using CVXopt as an educational quadratic programming solver, the integration of kernels into the SVM formulation is demonstrated, enabling clear visualization of nonlinear decision boundaries and soft margins. Key kernels, such as Polynomial and Linear, are discussed for their role in transforming data to achieve linear separability. The 'C' parameter's function in defining hard or soft margins is detailed, accommodating perfectly separable or overlapping datasets. The SVM fitting process, identifying Alphas, support vectors, and the intercept, relies on quadratic programming. While CVXopt is educational, real-world SVM implementations typically use libraries like libsvm. The content also reviews kernel functions' role in feature set translation and previews advanced topics like scikit-learn SVM parameters and multi-class classification, emphasizing appropriate kernel selection and margin flexibility.
#
# TOPICS:
#  ['Machine Learning']
#
# Q&A:
#  Q: What is the main focus of Part 32 of the machine learning tutorial?
# A: working with CVX opt and working with kernels being applied uh to our support Vector machine
# Q: Why is CVX opt useful in this specific tutorial's context?
# A: so you can see directly the impact of a kernel and where it's actually being injected and change
# Q: How can one learn more about working specifically with CVX opt?
# A: you can check that out if you want to learn more about working specifically with CVX opt
# Q: When would someone typically use libsvm instead of CVX opt for a Support Vector Machine?
# A: if you wanted to write your own [support vector machine] you would almost certainly be using lib svm
# Q: Who is credited with the example code used in this tutorial?
# A: I grabbed this from uh Matthew blondell's GitHub
#
# KEY CONCEPTS:
#  machine learning, CVX opt, kernels, support Vector machine, GitHub, pattern recognition, lib svm, scikit-learn, quadratic programming solver, soft margin, constraints, nonlinear
# Saved row 1 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 2: How to create high-quality outputs with ChatGPT Prompt Engineering | Unlocking the Power of Prompts
# ================================================================================
#
# SUMMARY:
#  Prompts serve as foundational inputs in prompt engineering, furnishing Large Language Models (LLMs) with essential context and constraints for generating specific text outputs. A comprehensive understanding of various prompt types—including questions, statements, and those incorporating multiple inputs or explicit constraints—is crucial for achieving desired output quality and complexity. Key features defining a prompt encompass its length, specific language, and explicit constraints regarding tone, style, or format, effectively communicating both the expected content and its desired execution. For instance, specifying a one-word answer for a factual query demonstrates the impact of well-defined constraints. Deconstructing prompts into individual components allows for precise identification of requirements and limitations, such as generating a 1000-word SEO-optimized blog. This systematic approach ensures meticulous control over LLM behavior and output.
#
# TOPICS:
#  ['Prompt Engineering', 'Generative AI', 'Natural Language Processing']
#
# Q&A:
#  Q: What are prompts in the context of prompt engineering?
# A: Prompts are the inputs that we give to our prompt engineering models.
# Q: Why is it important to understand prompts?
# A: It's important to understand prompts because they are the starting point for generating the text outputs.
# Q: How does the type of prompt chosen impact the output?
# A: The type of prompt you choose can also impact the complexity and the quality of your output.
# Q: What two key things define a prompt and influence output accuracy?
# A: What you expect and how you want it to be done define the prompt and get you more accurate output.
# Q: How is a prompt deconstructed?
# A: Deconstructing a prompt is the process of breaking it down into individual components to better understand the key feature and constraint.
#
# KEY CONCEPTS:
#  Prompt Engineering, Prompts, Large Language Models, Text Outputs, Constraints, Question Prompts, Specific Language, Python Code, Deconstruction of Prompts, Pre-trained Models, SEO Optimization
# Saved row 2 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 3: LangGraph Crash Course #3 - Agents & Tools - Intro
# ================================================================================
#
# SUMMARY:
#  AI agents are autonomous problem-solvers in artificial intelligence, designed for independent decision-making and leveraging external 'tools' such as calculators or search engines to accomplish tasks. A key method for developing these agents is the ReAct pattern, which combines Reasoning and Acting to mimic human cognitive processes. This iterative cycle involves a Large Language Model (LLM) first analyzing a problem ('thinking'), then deciding on an 'action,' potentially utilizing a tool. If a tool is required, the LLM provides specific 'action input' for its execution. The system then executes the tool, and the LLM 'observes' the output, repeating this cycle until a solution is reached. Fundamentally, AI agents integrate an LLM's reasoning capabilities with external tools to effectively navigate and solve complex problems.
#
# TOPICS:
#  ['LangChain', 'Python Programming', 'Agentic AI']
#
# Q&A:
#  Q: What are Artificial Intelligence (AI) agents?
# A: Agents are the problem solvers of the Artificial Intelligence (AI) World, capable of thinking on their own.
# Q: How do AI agents differ from chains and routers?
# A: Chains and routers follow specific instructions, but agents can decide for themselves what steps to take on their own.
# Q: What is the React agent pattern?
# A: The React agent pattern is one of the best known patterns to build agents, standing for reasoning plus acting.
# Q: How does the React pattern mimic human thinking?
# A: The React pattern is sort of mimicking how human beings think, first thinking about the problem.
# Q: When does the think-action-observation cycle of the React pattern end?
# A: The cycle is over if the agent gets the answer, otherwise it loops until the final answer is obtained.
#
# KEY CONCEPTS:
#  AI agents, Autonomous decisions, Tools, React agent pattern, Reasoning plus acting (ReAct), Think action observation, LLM (Large Language Model), Action input, LangChain, Control flow, LangGraph, API calls
# Saved row 3 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 4: LangGraph Crash Course #9 - Reflection Agent - LangSmith Tracing
# ================================================================================
#
# SUMMARY:
#  This summary outlines the comprehensive tracing and monitoring of AI agent workflows, specifically focusing on a reflection agent system. Utilizing Lsmith, integrated with LangChain, the process captures every operational step, enabling detailed observation of entire runs and individual traces. The objective is to understand the precise operational mechanics and synergistic functioning of interconnected components for optimized content generation. A practical demonstration illustrates a multi-iteration tweet generation process where a generation agent drafts content, and a reflection agent critically evaluates it, offering specific improvement suggestions. This iterative feedback loop, a generate-reflect-regenerate cycle, repeats several times to produce a highly refined tweet, underscoring the efficacy of reflection agents in facilitating deep thinking and iterative refinement for complex tasks.
#
# TOPICS:
#  ['Agentic AI', 'LangChain']
#
# Q&A:
#  Q: What is the primary objective of tracing the reflection agent system?
# A: understand exactly what is happening where
# Q: Why is it crucial to understand how both systems work together?
# A: to deliver our final refined viral tweet
# Q: How will the speaker initiate the process of understanding the system's operation?
# A: I'm just going to go ahead to this particular website smith. chain.
# Q: Who built the reflection agent system that is being traced?
# A: we built
# Q: When will the detailed tracing of the system take place?
# A: in this section
#
# KEY CONCEPTS:
#  reflection agent system, agent system, agent, reflection, system, smith. chain, refinement, tweet, tracing, virality
# Saved row 4 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 5: LangChain Crash Course #7 - Chat Models - Setup
# ================================================================================
#
# SUMMARY:
#  Integrating LangChain with OpenAI's chat models requires installing `langchain-openai`, importing `ChatOpenAI`, and initializing a model instance, such as `gpt-4o` or `gpt-3`, to access conversational AI capabilities. Interaction with the LLM API is primarily through the `llm.invoke()` method for sending prompts and receiving responses. Crucial for secure access is resolving the `API key is missing` error by creating an `.env` file with `OPENAI_API_KEY`, installing `python-dotenv`, and calling `load_dotenv()`. API responses, typically from OpenAI, contain comprehensive data, from which the `result.content` property is extracted for core output. Account balance issues must be rectified via billing settings. While basic single-turn prompts are possible, providing the LLM with a complete conversation history significantly enhances response quality, relevance, and coherence by furnishing full contextual data.
#
# TOPICS:
#  ['Deep Learning', 'Generative AI', 'LangChain']
#
# Q&A:
#  Q: What is the primary API the speaker will be predominantly working with in this section?
# A: open Artificial Intelligence (AI) apis
# Q: How is the `ChatOpenAI` class imported into the file?
# A: from longchain open Artificial Intelligence (AI) ... we want to import the chat open Artificial Intelligence (AI) class
# Q: Why is the `gpt-4o` model considered potentially expensive?
# A: because they are the most advanced model
# Q: When might a user choose to use `gpt-3.5` instead of `gpt-4o`?
# A: if you're a little short on cash you can always go with GPD 3.
# Q: What specific command is used to install the necessary LangChain package for OpenAI?
# A: install this package L chain Das open aai
#
# KEY CONCEPTS:
#  LangChain, Chat models, OpenAI APIs, ChatOpenAI, Package, Terminal, VS Code, Module, Class, LLM (Large Language Model), GPT-4o, GPT-3
# Saved row 5 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 6: Python Training Course - Python Sort List
# ================================================================================
#
# SUMMARY:
#  Python's `list.sort()` method exhibits specific behaviors when applied to lists containing strings or mixed data types. For string-only lists, the method sorts alphabetically, prioritizing uppercase letters over lowercase, with elements ordered alphabetically within each case. Applying `reverse=True` inverts this sequence, placing lowercase-initial strings before uppercase-initial strings, both in reverse alphabetical order. When a list comprises both strings and numbers, `sort()` successfully processes it by consistently placing all numerical elements before all string elements. Subsequently, numbers are sorted numerically and strings alphabetically, adhering to the aforementioned case-sensitive rules. This inherent sorting logic underscores the importance of data normalization, such as uniform casing, to achieve predictable and desired sorting outcomes in Python.
#
# TOPICS:
#  ['Python Programming']
#
# Q&A:
#  Q: What is the sorting order when a list contains strings with both uppercase and lowercase first letters?
# A: Sort puts words with a capital uppercase letter first, sorts them alphabetically, then sorts lowercase first letters alphabetically.
# Q: Why might a user need to make sure all strings are lowercase or all uppercase before sorting?
# A: You might have to make sure they were all lowercase or all uppercase if you wanted to sort them in a particular way.
# Q: How does Python's `sort()` method handle a list containing both strings and numbers?
# A: Python's sort method can handle lists that contain both strings and numbers, but it puts the numbers first and the strings.
# Q: When does the number appear at the end of the list after sorting?
# A: The number appears at the end of the list after the list has been sorted in reverse order.
# Q: Who is responsible for putting numbers first when sorting a list with mixed types?
# A: Python's sort method is responsible; it puts the numbers first and the strings.
#
# KEY CONCEPTS:
#  Python, Lists, Strings, Sort method, Numbers, Data types, Data structure, Uppercase, Lowercase, Alphabetical order, Reverse order
# Saved row 6 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 7: Humans vs. AI: Who should make the decision?
# ================================================================================
#
# SUMMARY:
#  Optimal human-AI decision-making hinges on understanding their distinct performance characteristics. AI demonstrates high success rates at extreme confidence levels but falters when uncertain, whereas humans exhibit flatter performance curves, often surpassing AI in accuracy during moderate uncertainty by integrating additional context. Augmented intelligence, a human-AI partnership, leverages these complementary strengths to achieve the highest success rates across a broad range of confidence scores. A critical challenge for this synergy is mitigating human cognitive biases, particularly automation bias—the tendency to over-rely on AI suggestions. Strategic presentation of AI recommendations is crucial; displaying them *after* a human forms an initial impression significantly reduces this bias, while paradoxically, revealing AI's accuracy percentage can decrease human trust. Effective integration requires data-driven quantification of the optimal decision-maker for specific contexts and careful design to counteract biases, thereby enhancing overall decision outcomes.
#
# TOPICS:
#  ['Artificial Intelligence', 'Machine Learning', 'Statistics']
#
# Q&A:
#  Q: Who should make a single decision when humans and AI have different strengths?
# A: The answer is a fascinating combination of holistic curves and human bias.
# Q: What is the main problem financial analysts face with fraud detection alerts?
# A: The analysts are overwhelmed with 90 percent of those alerts being false positives.
# Q: How is the confidence score represented on the graph?
# A: Along the X axis is the confidence score.
# Q: When does an Artificial Intelligence (AI) system typically have a lower success rate?
# A: Lower success rate when the Artificial Intelligence (AI) is not sure about a given prediction.
# Q: Why is the decision of who should decide (human or AI) complex?
# A: Humans can outperform AI at some tasks, but AI will make a better job for other tasks.
#
# KEY CONCEPTS:
#  Artificial Intelligence (AI), fraud detection system, fraudulent transactions, alerts, false positives, success rate, prediction, confidence score, AI performance curve, algorithm, human performance curves
# Saved row 7 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 8: Build generative apps faster with Vertex AI
# ================================================================================
#
# SUMMARY:
#  Google Cloud AI has significantly enhanced Vertex AI with new APIs and service improvements, aiming to streamline the development of enterprise-grade generative applications. A central focus is "grounding" these applications to ensure reliable access to accurate enterprise data, thereby addressing common technical challenges. Key technical offerings include a Document Understanding API for processing complex document structures, substantial performance improvements to the Embedding API, and Vector Search enhancements enabling hybrid queries leveraging Google's scalable infrastructure. Further additions comprise a Ranking API to optimize result relevance for Large Language Models, a Gemini-powered Grounded Generation API for producing cited answers, and a Check Grounding API for fact-checking statements against provided evidence. These high-quality, standalone primitives integrate Google's deep expertise, empowering developers to build more reliable and sophisticated generative AI solutions that integrate seamlessly into existing workflows.
#
# TOPICS:
#  ['Natural Language Processing', 'Deep Learning', 'Generative AI']
#
# Q&A:
#  Q: Who is Demetrius and what is his role at Google?
# A: Demetrius Case is a product manager within Cloud AI, focusing mostly on search and document Artificial Intelligence.
# Q: What is one of the key challenges developers face when building generative applications for enterprises?
# A: Grounding, which is making applications reliably access the right Enterprise data to produce accurate and consistent responses.
# Q: How does the Document Understanding API help improve the quality of applications?
# A: It uses Google's know-how from Document AI to understand document structure, helping improve the quality of applications.
# Q: Why are the new Vertex AI APIs considered unique or high quality?
# A: They embed a lot of Google know-how and special knowledge to produce solutions that solve problems really well.
# Q: How can developers integrate these new APIs into their workflow?
# A: Developers can integrate them as simple, standalone, stateless APIs with clear interfaces, or through popular frameworks like LangChain or LlamaIndex.
#
# KEY CONCEPTS:
#  Vertex AI, Generative applications, Grounding, Document understanding API, Embedding API, Vector search, Ranking API, LLM model, Grounded generation API, Check grounding API, LangChain, LlamaIndex
# Saved row 8 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 9: Unitary Transformations
# ================================================================================
#
# SUMMARY:
#  Unitary matrices are fundamental to the Singular Value Decomposition (SVD), which expresses a matrix X as UΣVᵀ. These transformations are crucial as they preserve vector lengths and angles, effectively representing pure rotations. For real-valued data, a unitary matrix U satisfies UᵀU = I, a property that extends to the complex conjugate transpose for complex data; the Fourier transform serves as a prominent example. Geometrically, SVD elucidates that a matrix X maps a unit sphere in its row space to an ellipsoid in its column space. Here, the singular values (Σ) dictate the lengths of the ellipsoid's principal axes, and the left singular vectors (U) define its orientation. Consequently, SVD offers a profound geometric understanding of data transformations by decomposing a matrix's action into a sequence of rotation, scaling, and a final rotation.
#
# TOPICS:
#  ['Machine Learning', 'Data Science', 'Statistics']
#
# Q&A:
#  Q: What defines a unitary matrix?
# A: A unitary matrix U is defined such that U U transpose equals U transpose U equals an identity matrix.
# Q: How do unitary transformations affect vectors in a vector space?
# A: Unitary transformations just rotate vectors, but they don't change the length or the angles between them.
# Q: Why is it important that unitary transformations preserve angles and lengths?
# A: Preserving angles and lengths is important for understanding the geometry and how vectors are related in that vector space.
# Q: When is the complex conjugate transpose used instead of the regular transpose?
# A: The complex conjugate transpose is used when dealing with complex valued data or complex matrices.
# Q: What geometric shape results from multiplying a sphere of unit vectors by a matrix X?
# A: Multiplying a sphere of unit vectors by a matrix X maps it into a large ellipsoid.
#
# KEY CONCEPTS:
#  Singular Value Decomposition (SVD), Unitary matrices, Matrix, Identity matrix, Economy SVD, Fourier transform, Vector space, Inner product, Complex conjugate transpose, Ellipsoid, Singular values, Singular vectors
# Saved row 9 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 10: Hands On With Google Gemini 1.5 Pro- Is this the Best LLM Model?
# ================================================================================
# WARNING:__main__:Gemini call failed (1/3): HTTPConnectionPool(host='localhost', port=41319): Read timed out. (read timeout=600.0)
# WARNING:__main__:Gemini call failed (2/3): HTTPConnectionPool(host='localhost', port=41319): Read timed out. (read timeout=600.0)
# WARNING:__main__:Gemini call failed (3/3): HTTPConnectionPool(host='localhost', port=41319): Read timed out. (read timeout=600.0)
# ERROR:__main__:Gemini failed after all retries — returning empty string.
# WARNING:__main__:Gemini call failed (1/3): HTTPConnectionPool(host='localhost', port=41319): Read timed out. (read timeout=600.0)
# WARNING:__main__:Gemini call failed (2/3): HTTPConnectionPool(host='localhost', port=41319): Read timed out. (read timeout=600.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1974274387.py in <cell line: 0>()
#     484 # 12. RUN GENERATION ONLY
#     485 #####################################################################
# --> 486 df_out = run_pipeline()
#     487 print("\nRole-based generation pipeline completed (NO evaluation).")
#
# /tmp/ipython-input-1974274387.py in run_pipeline()
#     449
#     450         try:
# --> 451             summary  = generate_summary(transcript)
#     452             topics   = classify_topic(transcript, summary)
#     453             qa_text  = generate_qa(transcript)
#
# /tmp/ipython-input-1974274387.py in generate_summary(transcript)
#     335     for i, c in enumerate(chunks, start=1):
#     336         logger.info(f"Summarisation (role-based) – chunk {i}/{len(chunks)}")
# --> 337         chunk_summary = summariser.run(c)
#     338         if not chunk_summary:
#     339             chunk_summary = ""
#
# /tmp/ipython-input-1974274387.py in run(self, t)
#     200
#     201     def run(self, t: str) -> str:
# --> 202         txt = self._run(self.build_prompt(t))
#     203         if not txt:
#     204             return "ERROR"
#
# /tmp/ipython-input-1974274387.py in _run(self, prompt)
#     170
#     171     def _run(self, prompt: str) -> str:
# --> 172         return gemini_call(prompt, temperature=self.temperature)
#     173
#     174
#
# /tmp/ipython-input-1974274387.py in gemini_call(prompt, temperature, retries)
#     150     for attempt in range(1, retries+1):
#     151         try:
# --> 152             resp = model.generate_content(prompt, generation_config=cfg)
#     153             LAST_TS = time.time()
#     154             return (getattr(resp, "text", "") or "").strip()
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      73     def error_remapped_callable(*args, **kwargs):
#      74         try:
# ---> 75             return callable_(*args, **kwargs)
#      76         except grpc.RpcError as exc:
#      77             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1146
#    1147             # Send the request
# -> 1148             response = GenerativeServiceRestTransport._GenerateContent._get_response(
#    1149                 self._host,
#    1150                 metadata,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in _get_response(host, metadata, query_params, session, timeout, transcoded_request, body)
#    1046             headers = dict(metadata)
#    1047             headers["Content-Type"] = "application/json"
# -> 1048             response = getattr(session, method)(
#    1049                 "{host}{uri}".format(host=host, uri=uri),
#    1050                 timeout=timeout,
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.12/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     535
#     536         with TimeoutGuard(remaining_time) as guard:
# --> 537             response = super(AuthorizedSession, self).request(
#     538                 method,
#     539                 url,
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
#####################################################################
# 1. MOUNT DRIVE & IMPORTS
#####################################################################
from google.colab import drive
drive.mount('/content/drive')

import os, re, json, time, logging
from datetime import datetime
from pathlib import Path
from typing import List, Dict, Any

import pandas as pd
import numpy as np
import google.generativeai as genai


#####################################################################
# 2. PATHS & API KEY
#####################################################################
INPUT_FILE = "/content/drive/MyDrive/Final Thesis Code/Input/clean_input_30.xlsx"

BASE_OUT = Path("/content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/")
BASE_OUT.mkdir(parents=True, exist_ok=True)

FINAL_OUTPUT_FILE = BASE_OUT / "gemini-2.5-flash_role_full_output.xlsx"

API_KEY_PATH = "/content/drive/MyDrive/Final Thesis Code/api_keys/gemini_key4.txt"

def load_key(path: str) -> str:
    with open(path, "r") as f:
        return f.read().strip()

API_KEY = load_key(API_KEY_PATH)
os.environ["GOOGLE_API_KEY"] = API_KEY
genai.configure(api_key=API_KEY)

print("Input file:", INPUT_FILE)
print("Output folder:", BASE_OUT)
print("Gemini key loaded ✓")


#####################################################################
# 3. GLOBAL CONFIG
#####################################################################
MODEL_NAME     = "gemini-2.5-flash"
MAX_CHARS      = 2600
GLOBAL_MIN_GAP = 70       # seconds between calls (soft global wait)
LAST_TS        = 0.0

VALID_TOPICS = [
    "Natural Language Processing","Artificial Intelligence","Prompt Engineering",
    "Machine Learning","Deep Learning","Reinforcement Learning","Generative AI",
    "Data Science","Time Series","Statistics","LangChain","Langraph",
    "Python Programming","Mlops","Agentic AI","Other"
]


#####################################################################
# 4. LOGGING
#####################################################################
def setup_logging():
    logs = Path("/content/logs")
    logs.mkdir(exist_ok=True)
    logfile = logs / f"log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt"

    logging.basicConfig(
        level=logging.INFO,
        handlers=[
            logging.FileHandler(logfile, encoding="utf-8"),
            logging.StreamHandler()
        ],
        format="%(asctime)s | %(levelname)s | %(message)s",
    )
    return logging.getLogger(__name__)

logger = setup_logging()


#####################################################################
# 5. CLEANING, SANITISE & CHUNKING
#####################################################################
def deep_clean(text: str) -> str:
    t = str(text)
    t = re.sub(r'https?://\S+|www\.\S+', ' ', t)
    t = re.sub(r'\b[\w\.-]+@[\w\.-]+\.\w+\b', ' ', t)
    t = re.sub(r'\[.*?\]|\(.*?\)', ' ', t)
    t = re.sub(r'\s+', ' ', t)
    # acronym expansion
    t = re.sub(r'\bNLP\b', 'Natural Language Processing (NLP)', t)
    t = re.sub(r'\bML\b', 'Machine Learning (ML)', t)
    t = re.sub(r'\bAI\b', 'Artificial Intelligence (AI)', t)
    return t.strip()

def sanitize(text: str) -> str:
    """Light sanitisation for prompts (keeps content, flattens whitespace)."""
    return re.sub(r'\s+', ' ', str(text)).strip()

def chunk_text(text: str, max_chars: int = MAX_CHARS) -> List[str]:
    clean = deep_clean(text)
    if len(clean) <= max_chars:
        return [clean] if clean else [""]
    sents = [s.strip() for s in re.split(r'(?<=[.!?])\s+', clean) if s.strip()]
    chunks, cur = [], ""
    for s in sents:
        if len(cur) + len(s) + 1 <= max_chars:
            cur = (cur + " " + s).strip()
        else:
            if cur:
                chunks.append(cur)
            cur = s
    if cur:
        chunks.append(cur)
    return chunks or [""]


#####################################################################
# 6. JSON EXTRACTION
#####################################################################
def extract_json(text: str) -> Dict[str, Any]:
    """Extract outermost {...} and parse as JSON."""
    if not text:
        return {}
    start = text.find("{")
    end = text.rfind("}")
    if start == -1 or end == -1 or end <= start:
        return {}
    candidate = text[start:end+1]
    try:
        return json.loads(candidate)
    except Exception:
        return {}


#####################################################################
# 7. GEMINI CALL WITH GLOBAL WAIT
#####################################################################
def gemini_call(prompt: str, temperature: float = 0.2, retries: int = 3) -> str:
    global LAST_TS
    now = time.time()

    # soft global rate limiting
    if LAST_TS > 0 and now - LAST_TS < GLOBAL_MIN_GAP:
        wait = GLOBAL_MIN_GAP - (now - LAST_TS)
        logger.info(f"Waiting {wait:.1f}s (respecting global gap)")
        time.sleep(wait)

    model = genai.GenerativeModel(MODEL_NAME)
    cfg = {"temperature": temperature}

    for attempt in range(1, retries+1):
        try:
            resp = model.generate_content(prompt, generation_config=cfg)
            LAST_TS = time.time()
            return (getattr(resp, "text", "") or "").strip()
        except Exception as e:
            logger.warning(f"Gemini call failed ({attempt}/{retries}): {e}")
            time.sleep(4 * attempt)

    logger.error("Gemini failed after all retries — returning empty string.")
    return ""


#####################################################################
# 8. ROLE-BASED TASK BASE CLASS
#####################################################################
class GeminiRoleTask:
    """Thin wrapper that reuses gemini_call + global wait."""
    def __init__(self, temperature: float = 0.2):
        self.temperature = temperature

    def _run(self, prompt: str) -> str:
        return gemini_call(prompt, temperature=self.temperature)


#####################################################################
# 9. ROLE-BASED TASK CLASSES
#####################################################################

class SummarisationRole(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        t = sanitize(t)
        return f"""
You are an **Educational Content Summariser** working for a university’s online learning platform.

Your role:
- Summarise lectures and AI/ML transcripts into concise, academic English.
- Highlight only key insights, definitions, examples, and outcomes.

Guidelines:
- Write 120–150 words (5–6 sentences).
- Avoid filler phrases like “the video discusses”.
- Use direct, objective tone suitable for academic notes.
- End with one line capturing the overall insight.

Return JSON only:
{{"generated_summary": "<summary text>"}}

Transcript :
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> str:
        txt = self._run(self.build_prompt(t))
        if not txt:
            return "ERROR"
        try:
            return json.loads(txt).get("generated_summary", "").strip()
        except Exception:
            s, e = txt.find("{"), txt.rfind("}")
            if s != -1 and e != -1:
                try:
                    return json.loads(txt[s:e+1]).get("generated_summary", "").strip()
                except Exception:
                    pass
        return txt.strip()[:2000]


class TopicRoleMulti(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        topics = ", ".join(VALID_TOPICS)
        t = sanitize(t)
        return f"""
You are a **Research Domain Classifier** for AI and ML educational transcripts.

Role Description:
You are an academic expert responsible for categorising transcripts into precise research areas based on terminology, algorithms, or learning paradigms mentioned.

Decision Guidelines:
- Identify the technical scope and key methods discussed.
- Select up to THREE relevant topics from the list below.
- Prefer domain-specific categories (e.g., "Reinforcement Learning") over broad ones (e.g., "Machine Learning").
- Avoid guessing: only include topics clearly supported by evidence in the text.

AVAILABLE TOPICS:
{topics}

Output Format:
Return valid one-line JSON only:
{{"predicted_topics":["<TOPIC1>","<TOPIC2>",...]}}

Transcript:
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> List[str]:
        raw = self._run(self.build_prompt(t))
        if not raw:
            return ["Other"]
        try:
            obj = json.loads(raw)
            tp = obj.get("predicted_topics", [])
            if isinstance(tp, str):
                tp = [tp]
        except Exception:
            tp = [v for v in VALID_TOPICS if v.lower() in raw.lower()]
        tp = [x for x in tp if x in VALID_TOPICS]
        return tp or ["Other"]


class QARole(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        t = sanitize(t)
        return f"""
You are an **Academic Question Author** who designs comprehension questions from lecture transcripts.

Role Objectives:
- Draft 5 short-answer questions to test conceptual understanding.
- Use “What, Why, How, When, Who” formats.
- Each answer must come verbatim or closely from transcript phrases (≤25 words).

Return JSON only:
{{"generated_questions":[{{"q":"...","a":"..."}},...]}}

Transcript :
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> List[Dict[str, str]]:
        txt = self._run(self.build_prompt(t))
        if not txt:
            return []
        try:
            return json.loads(txt).get("generated_questions", [])
        except Exception:
            s, e = txt.find("{"), txt.rfind("}")
            if s != -1 and e != -1:
                try:
                    return json.loads(txt[s:e+1]).get("generated_questions", [])
                except Exception:
                    pass
        return []


class ConceptRole(GeminiRoleTask):
    def build_prompt(self, t: str) -> str:
        t = sanitize(t)
        return f"""
You are an **AI Glossary Curator** creating concise glossaries for students.

Your Role:
- Extract exactly 10–12 distinct key technical terms, tools, or concepts.
- Focus on ML, NLP, Agentic AI, and related domain-specific nouns.
- Remove words like “video”, “lesson”, “concept”, “people”.

Return JSON only:
{{"key_concepts":["concept1","concept2",...]}}

Transcript :
\"\"\"{t}\"\"\""""

    def run(self, t: str) -> List[str]:
        txt = self._run(self.build_prompt(t))
        if not txt:
            return []
        try:
            return json.loads(txt).get("key_concepts", [])
        except Exception:
            s, e = txt.find("{"), txt.rfind("}")
            if s != -1 and e != -1:
                try:
                    return json.loads(txt[s:e+1]).get("key_concepts", [])
                except Exception:
                    pass
        return []


#####################################################################
# 10. ROLE-BASED TASK WRAPPERS (MATCH OLD FUNCTION SIGNATURES)
#####################################################################

# 10.1 ROLE-BASED SUMMARISATION (still hierarchical: per-chunk + final combine)
def generate_summary(transcript: str) -> str:
    chunks = chunk_text(transcript)
    partial_summaries: List[str] = []

    summariser = SummarisationRole(temperature=0.18)

    for i, c in enumerate(chunks, start=1):
        logger.info(f"Summarisation (role-based) – chunk {i}/{len(chunks)}")
        chunk_summary = summariser.run(c)
        if not chunk_summary:
            chunk_summary = ""
        partial_summaries.append(chunk_summary)

    combined = " ".join(p for p in partial_summaries if p)

    # Final combine using a simple JSON instruction (kept same style)
    final_prompt = f"""
Combine the following draft summaries into ONE coherent summary.

Requirements:
- Length: 120–160 words.
- Academic tone.
- Preserve main technical ideas and conclusions.
- No bullet points, no headings, no reasoning.

Return ONLY JSON:
{{"generated_summary":"<summary text>"}}

Draft Summaries:
\"\"\"{combined}\"\"\""""

    out2 = gemini_call(final_prompt, temperature=0.18)
    j2 = extract_json(out2)
    final_summary = j2.get("generated_summary", "").strip()
    if not final_summary:
        final_summary = out2.strip()[:900]
    return final_summary


# 10.2 ROLE-BASED TOPIC CLASSIFICATION (multi-label)
def classify_topic(transcript: str, summary: str) -> List[str]:
    # Use first chunk to keep tokens bounded (same as before)
    first_chunk = chunk_text(transcript)[0]
    classifier = TopicRoleMulti(temperature=0.22)
    topics = classifier.run(first_chunk)

    # Normalise + max 3 + fallback already handled in TopicRoleMulti
    cleaned: List[str] = []
    for t in topics:
        t = str(t).strip()
        for v in VALID_TOPICS:
            if t.lower() == v.lower():
                cleaned.append(v)
                break
    cleaned = list(dict.fromkeys(cleaned))[:3]
    return cleaned or ["Other"]


# 10.3 ROLE-BASED Q&A GENERATION
def generate_qa(transcript: str) -> str:
    first_chunk = chunk_text(transcript)[0]
    qa_task = QARole(temperature=0.15)
    qas = qa_task.run(first_chunk)

    lines: List[str] = []
    if isinstance(qas, list):
        for qa in qas:
            q = str(qa.get("q", "")).strip()
            a = str(qa.get("a", "")).strip()
            if q:
                lines.append(f"Q: {q}")
            if a:
                lines.append(f"A: {a}")
    return "\n".join(lines).strip()


# 10.4 ROLE-BASED KEY CONCEPT EXTRACTION
def generate_concepts(transcript: str) -> str:
    first_chunk = chunk_text(transcript)[0]
    concept_task = ConceptRole(temperature=0.22)
    concepts = concept_task.run(first_chunk)

    cleaned: List[str] = []
    if isinstance(concepts, list):
        for c in concepts:
            c2 = str(c).strip()
            if c2:
                cleaned.append(c2)
    return ", ".join(cleaned)


#####################################################################
# 11. MAIN PIPELINE — GENERATION ONLY (NO EVALUATION)
#####################################################################
def run_pipeline() -> pd.DataFrame:
    df = pd.read_excel(INPUT_FILE)
    results: List[Dict[str, Any]] = []

    if FINAL_OUTPUT_FILE.exists():
        old = pd.read_excel(FINAL_OUTPUT_FILE)
        if "row_index" in old.columns:
            done = set(old["row_index"])
            results = old.to_dict(orient="records")
            print(f"Resuming: {len(done)} rows already processed.")
        else:
            done = set()
    else:
        done = set()

    for idx, row in df.iterrows():
        if idx in done:
            print(f"Skipping row {idx} (already done)")
            continue

        title = str(row.get("title", "")).strip()
        transcript = str(row.get("transcript", "")).strip()

        print("\n" + "="*80)
        print(f"PROCESSING ROW {idx}: {title}")
        print("="*80)

        try:
            summary  = generate_summary(transcript)
            topics   = classify_topic(transcript, summary)
            qa_text  = generate_qa(transcript)
            concepts = generate_concepts(transcript)
        except Exception as e:
            logger.error(f"Error row {idx}: {e}")
            summary, topics, qa_text, concepts = "", ["Other"], "", ""

        print("\nSUMMARY:\n", summary)
        print("\nTOPICS:\n", topics)
        print("\nQ&A:\n", qa_text)
        print("\nKEY CONCEPTS:\n", concepts)

        rec = {
            "row_index": idx,
            "title": title,
            "summary": summary,
            "topic_classification": ", ".join(topics),
            "Q_and_A": qa_text,
            "key_concepts": concepts
        }
        results.append(rec)

        pd.DataFrame(results).to_excel(FINAL_OUTPUT_FILE, index=False)
        print(f"Saved row {idx} → {FINAL_OUTPUT_FILE}")

    df_out = pd.DataFrame(results)
    df_out.to_excel(FINAL_OUTPUT_FILE, index=False)
    print("\nDONE. Final file saved:", FINAL_OUTPUT_FILE)
    return df_out


#####################################################################
# 12. RUN GENERATION ONLY
#####################################################################
df_out = run_pipeline()
print("\nRole-based generation pipeline completed (NO evaluation).")
# Out:
# Mounted at /content/drive
# Input file: /content/drive/MyDrive/Final Thesis Code/Input/clean_input_30.xlsx
# Output folder: /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash
# Gemini key loaded ✓
# Resuming: 10 rows already processed.
# Skipping row 0 (already done)
# Skipping row 1 (already done)
# Skipping row 2 (already done)
# Skipping row 3 (already done)
# Skipping row 4 (already done)
# Skipping row 5 (already done)
# Skipping row 6 (already done)
# Skipping row 7 (already done)
# Skipping row 8 (already done)
# Skipping row 9 (already done)
#
# ================================================================================
# PROCESSING ROW 10: Hands On With Google Gemini 1.5 Pro- Is this the Best LLM Model?
# ================================================================================
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2302.10ms
# SUMMARY:
#  Google Gemini Pro 1.5 represents a significant advancement in generative AI, featuring a unified multimodal architecture adept at processing and generating content from both text and image inputs. Its standout technical capability is an expansive 1 million-token context window, significantly surpassing prior models, which facilitates sophisticated analysis of vast datasets, including extensive documents, audio, and video. Demonstrations have showcased its precision in extracting specific details from lengthy transcripts, such as the Apollo 11 mission, and its capacity for abstract visual interpretation. Accessible via a free API key and the `google-generativeai` Python package, developers can leverage features like streaming responses and configurable prompt feedback. This model simplifies AI application development by centralizing multimodal functionalities, thereby enhancing efficiency and enabling advanced solutions for Retrieval-Augmented Generation, dynamic information retrieval, and conversational AI.
#
# TOPICS:
#  ['Generative AI', 'Deep Learning', 'Natural Language Processing']
#
# Q&A:
#  Q: What is Google Gemini Pro 1.5 described as?
# A: it's a kind of a multi model
# Q: Why is Google Gemini Pro 1.5 considered a multimodal model?
# A: it will be able to work with both text and images
# Q: How will the speaker demonstrate the Hands-On application of Gemini Pro 1.5?
# A: by running some of the code playing with both images and text.
# Q: When will the demo video for Google Gemini Pro 1.5 be shown?
# A: first of all I'm going to show you the demo video
# Q: Who is the speaker of this YouTube video?
# A: my name is krishn
#
# KEY CONCEPTS:
#  Generative Artificial Intelligence, Google Gemini Pro 1.5, Gemini Pro, AI-powered application, End-to-end projects, Code, Images, Text, Multimodel, API key, Long context understanding, Experimental feature
# Saved row 10 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 11: How to evaluate large language models using Prompt Engineering | Testing and Improving with PyTorch
# ================================================================================
#
# SUMMARY:
#  Robust evaluation and iterative refinement are essential for developing effective and generalizable prompt engineering models. This process involves assessing performance and reliability through key quantitative metrics such as perplexity, which measures a language model's predictive accuracy for word sequences (lower values indicating better performance), and accuracy, quantifying the correctness of generated responses. These are critically complemented by qualitative human evaluation. Debugging and improving models necessitate analyzing generated outputs to identify common errors and patterns, enabling targeted fine-tuning. Furthermore, testing models on diverse datasets and tasks, often utilizing techniques like cross-validation, is paramount to assess their ability to generalize to new or unseen data. This continuous evaluation and refinement cycle ensures prompt engineering models maintain optimal performance and adaptability.
#
# TOPICS:
#  ['Prompt Engineering', 'Natural Language Processing', 'Generative AI']
#
# Q&A:
#  Q: What are matrices used for when evaluating prompt engineering models?
# A: Matrices are used to measure the performance of the model and its ability to generate accurate and meaningful responses.
# Q: How is perplexity measured in a language model?
# A: Perplexity measures how well a language model predicts a sequence of words.
# Q: Why is testing prompt engineering models on different datasets or tasks important?
# A: By testing on different data or different tasks we can determine the model's ability to generalize on new or unseen data.
# Q: What is one common technique for debugging and improving prompt engineering models?
# A: One common technique is to analyze the generated response and identify common errors or patterns.
# Q: How does human evaluation contribute to assessing prompt engineering models?
# A: Human evaluation involves having human rate the quality of the responses.
#
# KEY CONCEPTS:
#  Prompt Engineering Models, Matrices, Perplexity, Accuracy, Human Evaluation, Language Model, Large Language Model, Generated Responses, Debugging, Fine-tune, Data Sets, Cross Validation
# Saved row 11 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 12: Generative AI vs AI agents vs Agentic AI
# ================================================================================
#
# SUMMARY:
#  Generative AI, typically employing Large Language Models (LLMs) with a knowledge cutoff, creates novel content by learning patterns from existing data. Building upon this, an AI Agent integrates LLMs with external tools and memory, enabling autonomous execution of specific, narrow tasks like web searches or flight bookings. The more advanced Agentic AI represents a system where multiple AI agents collaborate to achieve complex, multi-step goals. This involves sophisticated multi-step reasoning, planning, and coordination, often leveraging diverse tools and other agents, such as a flight booking agent coordinating with an immigration agent for visa checks. This progression from Generative AI to AI Agents and then to Agentic AI marks a significant increase in autonomous decision-making and the ability to address intricate, real-world problems.
#
# TOPICS:
#  ['Generative AI', 'Agentic AI', 'Langraph']
#
# Q&A:
#  Q: What is Generative Artificial Intelligence (AI)?
# A: Generative Artificial Intelligence (AI) is an AI that can create new content either text, image, or video based on patterns learned from existing data.
# Q: How can a Large Language Model (LLM) provide up-to-date information despite having a knowledge cutoff date?
# A: An LLM can call an API and fetch the latest price of a flight or other information, overcoming its knowledge cutoff.
# Q: Why is an Artificial Intelligence (AI) agent considered more capable than a simple Q&A chatbot?
# A: An AI agent will complete a task using tools, memory, and knowledge, unlike a simple Q&A chatbot.
# Q: What is the defining characteristic of an Agentic Artificial Intelligence (AI) system?
# A: Agentic AI is a system where one or more AI agents work autonomously, making decisions using tools and even other agents to reach a goal.
# Q: When does the complexity of tasks that an AI system can perform increase significantly?
# A: Complexity increases as you evolve from simple generative AI with only LLM, to AI agent, to agentic Artificial Intelligence (AI) systems.
#
# KEY CONCEPTS:
#  Generative Artificial Intelligence (AI), Large Language Model (LLM), Knowledge Cutoff, API, Artificial Intelligence (AI) Agent, Tools, Memory, Autonomy, Multi-step Reasoning, Multi-step Planning, Agentic Artificial Intelligence (AI), Frameworks
# Saved row 12 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 13: Covariance in Statistics
# ================================================================================
#
# SUMMARY:
#  Covariance is a fundamental statistical measure that quantifies the linear relationship between two random variables, X and Y. It is calculated as the average product of their deviations from their respective means, using the formula `Cov(X, Y) = (1/n) * Σ[(Xi - μX) * (Yi - μY)]`. A notable property is that the covariance of a variable with itself equals its variance. A positive covariance indicates a direct relationship where variables tend to increase or decrease together, while a negative covariance suggests an inverse relationship. Although covariance reveals the direction of association, it does not quantify the strength or magnitude of this relationship, a limitation addressed by correlation coefficients. Thus, covariance primarily offers a directional insight into how two variables co-vary.
#
# TOPICS:
#  ['Statistics', 'Data Science']
#
# Q&A:
#  Q: What is the primary purpose of covariance in data analysis?
# A: Covariance is helping us to quantify the relationship between random variables in a particular data set.
# Q: Why does covariance result in a negative value?
# A: Whenever we have a scenario where X is increasing Y is decreasing, our covariance will be negative.
# Q: How is the covariance of a variable with itself related to its variance?
# A: Covariance of X for X is nothing but variance of X.
# Q: When will the covariance between two variables be positive?
# A: Whenever X is increasing and Y is increasing, the covariance will be positive.
# Q: What is a key limitation of covariance?
# A: Covariance does not say how much positive or negative the relationship is.
#
# KEY CONCEPTS:
#  Statistics, Variance, Covariance, Data Pre-processing, Data Analysis, Random Variables, Equation, Mean, Parameters, Data Set, Pearson Correlation Coefficient, Features
# Saved row 13 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 14: 3. Objective || End to End AI Tutorial
# ================================================================================
#
# SUMMARY:
#  Reinforcement Learning (RL) defines its core objective as learning an optimal policy to maximize a cumulative numerical reward signal over time. An RL agent interacts with its environment through a trial-and-error process, making decisions based on observations and receiving feedback via reward signals that indicate action quality. This iterative process involves exploration, taking actions, observing resulting states and rewards, and subsequently updating its policy. The effective definition of this reward function is crucial for the agent to achieve its objective. In episodic tasks, such as Tic-Tac-Toe, rewards are typically defined at game completion (e.g., +1 for a win, -1 for a loss). For continuous tasks like stock market trading, the objective is to maximize profit, utilizing mathematical reward functions based on profit/loss or risk-adjusted measures.
#
# TOPICS:
#  ['Reinforcement Learning']
#
# Q&A:
#  Q: What is the objective of reinforcement learning?
# A: The objective of reinforcement learning is to learn the optimal policy that maximizes a numerical reward signal.
# Q: How does a reinforcement learning agent achieve its objective?
# A: It is achieved through trial and error learning, where the agent explores the environment, observes states and rewards, and updates its policy.
# Q: What is the ultimate goal of a reinforcement learning agent?
# A: The ultimate goal of an RL agent is to maximize the cumulative reward over time by learning optimal actions in each step.
# Q: Why is the reward signal important in reinforcement learning?
# A: The reward signal provides feedback to the agent about the quality of its actions, helping it understand how good or bad they were.
# Q: How can the reward be defined for a continuous task?
# A: For continuous tasks, the reward can be defined as the amount of profit earned over a given period of time.
#
# KEY CONCEPTS:
#  Reinforcement Learning, Agent, Objective, Episodic Task, Continuous Task, Optimal Policy, Reward Signal, Environment, Cumulative Reward, State, Action, Reward Function
# Saved row 14 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 15: Python Training - Python Dictionary Basics
# ================================================================================
#
# SUMMARY:
#  Python dictionaries function as mutable collections of unique key-value pairs, or items, enclosed in curly brackets. Keys must be immutable data types, such as strings or numbers, while values can be any data type. This structure facilitates efficient mapping, exemplified by its utility in associating stock price components (open, high, close) with their respective values. Core operations include retrieving all items, keys, or values using `.items()`, `.keys()`, and `.values()` methods, respectively. Dictionaries can be constructed from paired lists using the `zip()` function and the `dict()` constructor. Individual values are accessed, modified, or deleted by referencing their corresponding key within square brackets. Consequently, this fundamental data structure is crucial for data organization and serves as a cornerstone for advanced data science applications, particularly with libraries such as Pandas.
#
# TOPICS:
#  ['Python Programming']
#
# Q&A:
#  Q: What is a dictionary in Python made up of?
# A: A dictionary is made up of items, each item consists of a key value pair.
# Q: How are key-value pairs and items separated within a Python dictionary?
# A: The key value pairs are separated by a colon and the items are separated by a comma.
# Q: Why are dictionaries considered useful in Python?
# A: Dictionaries are useful for mapping one item to another.
# Q: How is a dictionary declared in Python?
# A: The dictionary is declared within curly brackets.
# Q: What is a fundamental requirement for a dictionary key in Python?
# A: The key has to be immutable so it can't change.
#
# KEY CONCEPTS:
#  Dictionary, Key-value pairs, Key, Value, Item, Immutable, String, List, Tuple, Zip function, Pandas, Data science
# Saved row 15 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 16: Fight Insider Threats with AI-infused SIEM
# ================================================================================
#
# SUMMARY:
#  Artificial Intelligence (AI) significantly enhances organizational security posture and addresses emerging threats. AI and automation adoption correlates with a 108-day reduction in the average time to identify and contain data breaches, as evidenced by IBM's 2023 Cost of a Data Breach Report. User Behavior Analytics (UBA), powered by AI and machine learning, is particularly effective for the rapid and precise detection and response to insider threats, which incur an average cost of $4 million per incident. Integrated with Security Information and Event Management (SIEM) solutions, such as IBM Security QRadar, UBA analyzes user behavior to detect anomalies and potential threats. The system learns normal user patterns, identifies risky employee behavior, maps identified tactics to MITRE ATT&CK, and provides natural language insights. This integration accelerates investigations from hours to minutes, enabling security teams to shift from reactive alert management to proactive defense efforts, thereby fortifying organizational defenses against pervasive and costly security risks.
#
# TOPICS:
#  ['Artificial Intelligence', 'Machine Learning']
#
# Q&A:
#  Q: What was a key finding for those that extensively used AI and automation regarding data breaches?
# A: It took 108 fewer days on average to identify and contain a data breach.
# Q: Why are Security Professionals constantly looking for ways to use AI?
# A: To stay ahead of emerging threats and improve your organization security posture.
# Q: How can User Behavior Analytics (UBA) help detect and respond to Insider threats?
# A: UBA with Artificial Intelligence (AI) and machine learning can help you detect and respond to Insider threats quickly and precisely.
# Q: When was the 'cost of a data breach report' that found faster containment for AI users published?
# A: IBM's cost of a data breach report 2023.
# Q: Who are Insider threats a major concern for?
# A: Insider threats are a major concern for organizations of all sizes.
#
# KEY CONCEPTS:
#  Artificial Intelligence (AI), automation, user Behavior analytics (UBA), machine learning, emerging threats, security posture, data breach, Insider threats, threat detection, threat response, data breach containment
# Saved row 16 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 17: Meta Llama 3 Is Here- And It Will Rule the Open Source LLM Models
# ================================================================================
#
# SUMMARY:
#  Meta has introduced Llama 3, an advanced open-source large language model available in 8 billion and 70 billion parameter versions. This LLM significantly enhances reasoning, code generation, and instruction following, having been trained on an extensive 50 trillion tokens with an 8K context length. Benchmark evaluations reveal its superior accuracy against other open-source models and strong competitiveness with leading proprietary LLMs. This advancement aligns with a broader trend where open-source models, such as Cloud 3 Sonnet, demonstrate competitive, and occasionally superior, performance against proprietary counterparts like GPT-4 across MMLU, HumanEval, and GSM8K, though mathematical reasoning remains an area for refinement. Llama 3 was developed under a comprehensive responsibility framework, emphasizing transparency. Its model weights and tokenizers are widely accessible via Meta's website, Hugging Face, and Kaggle, facilitating local deployment and widespread adoption for AI development.
#
# TOPICS:
#  ['Other']
#
# Q&A:
#  Q: Who is the speaker introducing himself as?
# A: my name is krishak
# Q: What platform is the speaker welcoming viewers to?
# A: my YouTube channel
# Q: When is the speaker recording this message?
# A: right now it is 2 a. m.
# Q: How does the speaker initially greet the audience?
# A: hello
# Q: Why does the speaker welcome the audience?
# A: welcome to my YouTube channel
#
# KEY CONCEPTS:
#  Machine Learning, Natural Language Processing, Neural Network, Deep Learning, Reinforcement Learning, Agentic AI, Large Language Model, Transformer, Recurrent Neural Network, Convolutional Neural Network, Data Science, Algorithm
# Saved row 17 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 18: Getting Started With sklearn
# ================================================================================
#
# SUMMARY:
#  This segment outlines the practical implementation of machine learning algorithms in Python for generating decision boundaries, emphasizing a step-by-step approach to writing classifier code. The methodology centers on utilizing the `scikit-learn` (sklearn) library, with the Gaussian Naive Bayes variant demonstrated as the specific algorithm. A crucial element of this practical instruction involves navigating online documentation, exemplified by searching for 'sklearn Naive Bayes,' to effectively identify and comprehend relevant functions. The primary learning objective is to empower students to execute the provided code, thereby prioritizing hands-on coding experience and practical application. A comprehensive theoretical explanation of Naive Bayes is intentionally deferred to subsequent lessons. This pedagogical strategy highlights the critical role of leveraging library documentation for the successful implementation of machine learning classifiers in Python.
#
# TOPICS:
#  ['Machine Learning', 'Python Programming']
#
# Q&A:
#  Q: What is the name of the Python library that will be used a lot in this lesson?
# A: The name of this library is scikit-learn, which is often abbreviated sk-learn.
# Q: Why is Google being used at the start of this lesson?
# A: We're going to be using Google to help us use the documentation of that library.
# Q: How will the speaker help students learn to use the library's functions?
# A: Using Google to help us use the documentation of that library to figure out how to use some of the functions.
# Q: What specific algorithm did the speaker use to write the classifier?
# A: Gaussian Naive Bayes, this is what the way that I actually wrote classifier that you just saw.
# Q: When will students be able to write the Python code themselves?
# A: By the end of the next video or two, you will be able to write this code yourself.
#
# KEY CONCEPTS:
#  Python code, decision boundary, Python library, documentation, functions, scikit-learn, sklearn, algorithm, Naive Bayes, Naive Bayes formula, Gaussian Naive Bayes, classifier
# Saved row 18 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 19: Log Normal Distribution in Statistics
# ================================================================================
#
# SUMMARY:
#  The lecture reviewed Gaussian (normal) distribution, defined by its symmetrical bell curve, central mean, and the 68-95-99.7 empirical rule, with human height as an example. It then introduced log-normal distribution, where a variable's logarithm is Gaussian. Unlike the symmetrical Gaussian, log-normal distributions are right-skewed with a 'fatter' tail, common in datasets like income or review lengths. Understanding these distributions is crucial for effective machine learning data preprocessing. For standardization, such as with Gaussian R&D spend and log-normal marketing spend, log-normal data first undergoes a logarithmic transformation to become Gaussian. Subsequently, standard scaling (mean=0, std dev=1) is applied across all features. This log normalization process ensures data consistency and significantly enhances model accuracy.
#
# TOPICS:
#  ['Statistics', 'Machine Learning', 'Data Science']
#
# Q&A:
#  Q: What is the defining characteristic of a Gaussian distribution's curve?
# A: It usually follows a bell curve where the right side is symmetrical to the left side.
# Q: Why are various distributions like Gaussian and log-normal learned in the context of data analysis?
# A: To give a model data in the same scale, which will result in higher accuracy for any algorithm applied.
# Q: How is a random variable determined to belong to a log normal distribution?
# A: A random variable belongs to a log normal distribution if the log of X is normally distributed.
# Q: When might a log normal distribution be observed in real-world data, according to the lecture?
# A: Examples include the income of people and the length of product review comments.
# Q: What is the entire process of converting log-normal data to a standard normal distribution called?
# A: This whole process is basically called as log normalization.
#
# KEY CONCEPTS:
#  Gaussian distribution, Normal distribution, Mean, Standard deviation, Bell curve, Log normal distribution, Random variable, Binomial distribution, Bernoulli's distribution, Standard normal distribution, Standard scaler, Log normalization
# Saved row 19 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 20: Deep learning project end to end | Potato Disease Classification Using CNN - 1 : Problem Statement
# ================================================================================
#
# SUMMARY:
#  This project outlines an end-to-end deep learning solution for potato disease detection, addressing significant agricultural economic losses caused by early and late blight. The system leverages Convolutional Neural Networks (CNNs) for accurate image classification, enabling farmers to diagnose plant health via a mobile application. The technical workflow encompasses collecting and augmenting diverse image data, building and training CNN models, and deploying them through a robust MLOps pipeline. This pipeline includes `TF Serving` for model management, a `FastAPI` backend, and Google Cloud Functions for cloud deployment, supporting a React Native mobile application. For mobile optimization, models are converted to `TF Lite` using quantization. This comprehensive approach provides precise, timely diagnostics, aiming to reduce agricultural waste and enhance farmer profitability. The project also serves as an educational framework, emphasizing practical skills in ML engineering and data science.
#
# TOPICS:
#  ['Deep Learning', 'Mlops', 'Data Science']
#
# Q&A:
#  Q: What is the primary domain for the deep learning project series discussed in the video?
# A: an end-to-end deep learning project series in agriculture domain.
# Q: Why are farmers who grow potatoes facing significant economic losses annually?
# A: because of various diseases that can happen to a potato plant.
# Q: How will the mobile application help farmers detect potato plant diseases?
# A: take a picture of the plant and the mobile application will tell them whether the potato plant is healthy or it has one of these diseases.
# Q: Who is the target user for the mobile application being developed by AtliQ Agriculture?
# A: a farmer.
# Q: When a data scientist starts working on this project for AtliQ Agriculture, what is their first task?
# A: gather in a room along with your colleagues and you will start discussing the technical architecture.
#
# KEY CONCEPTS:
#  Deep Learning Project, Data Collection, Model Building, ML Ops, TF Serving, FastAPI, Google Cloud (GCP), Google Cloud Functions, React Native, Artificial Intelligence (AI), Convolutional Neural Network (CNN), Data Analytics
# Saved row 20 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 21: LangGraph Crash Course #2 - Levels of Autonomy in LLM applications
# ================================================================================
#
# SUMMARY:
#  The evolution of Large Language Model (LLM) applications demonstrates a clear progression in autonomy, moving from basic, deterministic code and single LLM calls to highly adaptive agents. Initial approaches, such as hard-coded rules or one-to-one LLM interactions, are limited to simple tasks. Chains enhance complexity handling by linking multiple specialized LLM calls in fixed, sequential steps, though they remain rigid. A significant leap occurs with routers, where an LLM dynamically selects processing paths based on user input, acting as an intelligent controller. The pinnacle of this evolution is the State Machine, or Agent, which integrates routers with iterative loops, memory, and adaptive learning capabilities. Agents feature LLM-controlled flow, enabling continuous refinement, human interaction, and learning from errors, fundamentally distinguishing them from the one-directional nature of chains and routers. This architectural progression transforms LLMs from simple processors into intelligent, adaptive systems capable of managing complex, multi-step tasks.
#
# TOPICS:
#  ['Generative AI', 'Langraph', 'Agentic AI']
#
# Q&A:
#  Q: What is the primary characteristic of 'code' in terms of autonomy?
# A: Code has zero autonomy and is 100% deterministic.
# Q: Why is a single LLM call often insufficient for complex tasks?
# A: Trying to get everything done in one shot often leads to confused or mixed up responses.
# Q: How do 'chains' create a smarter system compared to a single LLM call?
# A: Each step is simple but together they create a much smarter system than a single llm call.
# Q: What is a key disadvantage of 'routers' despite their ability to choose different paths?
# A: While it can choose different parts it still cannot remember previous conversations or learn from mistakes.
# Q: When is an LLM application considered an 'agent'?
# A: Whenever the control flow is controlled by an llm it is then called an agent.
#
# KEY CONCEPTS:
#  LLM applications, Autonomy, LLM call, Chains, Router, State machine, Agent, Human in Loop, Multi-agent systems, Adaptive learning, LangGraph, Control flow
# Saved row 21 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 22: Introduction to Advanced Topics in Prompt Engineering using Pre-Trained Large Language Models
# ================================================================================
#
# SUMMARY:
#  Advanced prompt engineering necessitates a comprehensive approach to handling diverse prompt types, including text, image, and audio, each requiring specific pre-processing techniques. Model optimization is achieved through fine-tuning methods such as multitask learning, which fosters robust representations via simultaneous training on multiple tasks, and distillation, enhancing efficiency by enabling smaller models to mimic larger ones. Crucial data pre-processing steps involve tokenization for breaking text into units and normalization for standardizing formats, preventing ambiguity. For production accessibility, developed models can be deployed using frameworks like TensorFlow Serving or Flask. Paramount ethical considerations, addressing bias, fairness, and privacy, mandate the use of diverse and inclusive training data to mitigate discriminatory outcomes, underscoring the need for expertise across all these domains.
#
# TOPICS:
#  ['Natural Language Processing', 'Prompt Engineering', 'Deep Learning']
#
# Q&A:
#  Q: What are some different types of prompts that advanced prompt engineering handles?
# A: text-based prompt image based prompts and audio based prompts
# Q: How does multitask learning help a model?
# A: help the model learn more robust representation that can generalize to different users
# Q: Why is distillation used in model training?
# A: make the smaller model more efficient and run very faster than the larger models
# Q: What is tokenization in data pre-processing?
# A: breaking down the text into smaller units such as words or sub words
# Q: How can bias occur in prompt engineering models?
# A: when the data used to train the model is not representative of the whole population
#
# KEY CONCEPTS:
#  Prompt Engineering, Large Language Models, Pre-trained Models, Fine-tuning, Data Pre-processing, Tokenization, Normalization, Multitask Learning, Model Distillation, TensorFlow Serving, Flask, Data Augmentation
# Saved row 22 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 23: SVD: Eigen Action Heros [Matlab]
# ================================================================================
#
# SUMMARY:
#  This summary details the application of Singular Value Decomposition (SVD) and eigenfaces for image classification. The process involves collecting, aligning, and grayscaling images, then subtracting an average face before performing SVD to derive principal components, or eigenfaces. Projecting images into this eigenface space enables classification, exemplified by "eigen action heroes" like Arnold Schwarzenegger and Sylvester Stallone, which formed distinct clusters, leading to successful classification of test images. However, analysis with Taylor Swift revealed a limitation: while she separated well from Stallone, a surprising overlap with Schwarzenegger occurred. This demonstrates how naive pixel-based classification can be dominated by superficial features. Advanced systems address this by inferring 3D facial geometry. Overall, eigenfaces provide robust dimensionality reduction for image classification, but their performance is influenced by simple pixel correlations.
#
# TOPICS:
#  ['Machine Learning', 'Data Science']
#
# Q&A:
#  Q: What is the primary goal of the eigenfaces example demonstrated in the lecture?
# A: To find the eigen faces of a bunch of faces and use those to cluster two different people in eigen face space.
# Q: How were the images of Arnold Schwarzenegger and Sylvester Stallone prepared before being put into the 'a matrix'?
# A: Images were cropped and roughly aligned so that their faces were more or less in the same place and filling the same box.
# Q: Why did the projection of Taylor Swift and Arnold Schwarzenegger into eigenface space show more overlap than other pairs?
# A: Taylor Swift and Arnold Schwarzenegger are both fair-skinned blonde hair, having lighter pixels on average, leading to more correlation.
# Q: Who were the two action heroes initially used in the eigenfaces clustering example?
# A: The two action heroes initially used were Arnold Schwarzenegger and Sylvester Stallone.
# Q: When did Facebook's face classification technology achieve human-level accuracy?
# A: When they started to infer the three-dimensional geometry of the actual human head from 2D images.
#
# KEY CONCEPTS:
#  Singular Value Decomposition, Eigenfaces, Eigen face space, Clustering, Principal Component Analysis, Principal Components, Matrix, Column vector, Image classification, Training data, Test image, Deep neural network architectures
# Saved row 23 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 24: LangChain Crash Course #3 - What is LangChain?
# ================================================================================
#
# SUMMARY:
#  Large Language Models (LLMs) possess advanced reasoning but are inherently limited in their direct interaction with the real world. LangChain emerges as a critical framework designed to bridge this gap, connecting LLMs with external systems. It enables LLM-powered applications to communicate with real-world APIs, databases, and services, facilitating practical actions. This includes tasks such as sending emails, accessing booking platforms, resolving customer queries using private company databases, and comprehensive information retrieval through web browsing and scraping. A key benefit of LangChain is its modularity, allowing developers to seamlessly switch between different LLM models. Ultimately, LangChain transforms LLMs from mere analytical tools into active agents capable of practical engagement and influencing external environments, significantly extending AI's utility beyond computational intelligence to tangible real-world outcomes.
#
# TOPICS:
#  ['LangChain', 'Generative AI', 'Agentic AI']
#
# Q&A:
#  Q: What is one of the biggest limitations of large language models (LLMs) on their own?
# A: They cannot actually interact with the real world.
# Q: Why is a framework like LangChain needed when building applications with LLMs?
# A: To have the reasoning ability of an LLM and the ability to communicate with the real world.
# Q: How does LangChain function in the context of LLMs and the real world?
# A: Lang chain acts as a bridge between the llms and the real world.
# Q: When does LangChain come into the picture for application development?
# A: When an application needs the reasoning ability of an LLM and the ability to communicate with the real world.
# Q: Who or what does LangChain help to build applications using LLMs?
# A: Lang chain is by far the most popular framework that helps build applications using llms.
#
# KEY CONCEPTS:
#  LangChain, Large Language Model (LLM), GPT models, Chat application, APIs (Application Programming Interfaces), Databases, Framework, Artificial Intelligence (AI), Query, Interface, Data, Reasoning ability
# Saved row 24 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 25: How To Use Residuals For Time Series Forecasting
# ================================================================================
#
# SUMMARY:
#  Residuals in time series analysis, defined as the difference between a model's fitted and actual observed values, are crucial for diagnosing forecasting model performance. Ideal residuals should exhibit no autocorrelation and a mean of zero, signifying an unbiased forecast that has captured all relevant information. Autocorrelation is assessed using tools like Autocorrelation and Partial Autocorrelation Function (ACF/PACF) plots and the Ljung-Box statistical test; p-values below a 0.05 significance level indicate its presence, necessitating model refinement. Model bias is identified through a histogram of residuals, which ideally should be symmetrically centered around zero, with deviations suggesting systematic over or under-forecasting. Effectively diagnosing these issues, including autocorrelation and bias, is fundamental for validating and enhancing time series forecasting models, leading to improved forecast accuracy and reliability.
#
# TOPICS:
#  ['Time Series', 'Statistics', 'Python Programming']
#
# Q&A:
#  Q: What are residuals in time series analysis?
# A: Residuals are simply the difference between the fitted value and the actual value of the time series.
# Q: Why is it important to analyze your time series?
# A: Analyzing your time series is important because it allows you to diagnose essentially performance.
# Q: How can residual analysis help improve forecasting methods?
# A: We can use residual analysis to find out what the model is doing and how we can improve it.
# Q: What two characteristics should residuals ideally possess for a good model?
# A: Residuals should have no autocorrelation or partial autocorrelation, and the mean of the residual should be zero.
# Q: How can one quantify if there is indeed correlation in residuals?
# A: A better way of quantifying if there is indeed correlation in residuals is through the Young-Box test.
#
# KEY CONCEPTS:
#  Time Series, Residuals, Residual Analysis, Forecasting Methods, Python, Fitted Value, Autocorrelation, Partial Autocorrelation, Young Box Test, Holt-Winters Model, Bias, Test and Train Split
# Saved row 25 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 26: Build a Text-to-SQL Agent for Smarter Database Queries
# ================================================================================
#
# SUMMARY:
#  This project outlines the development of an Artificial Intelligence agent designed for natural language database interaction, utilizing large language models (LLMs) hosted on watsonx.ai within a LangGraph ReAct architecture. A Next.js frontend facilitates user interaction, incorporating UI/UX enhancements such as dynamic loading states and structured message rendering. The backend employs an in-memory SQLite database, configured with defined schemas for tables like `customer` and `order`, and populated with mock data. A `GetFromDB` tool, integrated via LangChain, enables the LLM to generate and execute SQL queries from natural language, providing explicit database schema context. The LLM demonstrates proficiency in translating diverse requests, from simple counts to complex join operations, into executable SQL. Crucial aspects include message serialization, environment configuration, and robust guardrails to ensure secure and controlled database access.
#
# TOPICS:
#  ['Agentic AI', 'Generative AI', 'Langraph']
#
# Q&A:
#  Q: What is the main purpose of the AI agent being built in this video?
# A: build an Artificial Intelligence (AI) agent that's able to talk to your database.
# Q: How will the AI agent utilize its SQL knowledge?
# A: use that SQL knowledge to connect to your databases.
# Q: Why is Tailwind being used in this project?
# A: We also will be using Tailwind, so we don't have to write any CSS.
# Q: When will the input element and button element be connected to functions?
# A: We'll be hooking up the input element and the button element to some functions later on.
# Q: Who might make slightly different choices when building their own project?
# A: If you build your own project, you might want to make slightly different choices.
#
# KEY CONCEPTS:
#  Artificial Intelligence (AI) agent, database, large language models, SQL, LangGraph, ReAct agent, Next.js, watsonx.ai, in-memory database, SQLite, TypeScript, Text2SQL agent
# Saved row 26 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 27: Learn Prompt Engineering from Scratch: Master the Art of Text Generation - Introduction
# ================================================================================
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 3141.46ms
# SUMMARY:
#  Prompt engineering is a specialized field within Natural Language Processing (NLP) dedicated to developing models that generate high-quality text outputs from user prompts. It leverages pre-trained Large Language Models (LLMs), such as GPT or Bard, which are fine-tuned for specific tasks and inputs. This approach significantly enhances applications like chatbots, language translation, and content generation by producing more accurate, coherent, and contextually appropriate text compared to traditional rule-based methods. However, prompt engineering models can struggle with complex or ambiguous prompts and may generate biased or inaccurate outputs due to underlying data or model architecture. The discipline encompasses prompt analysis, understanding its benefits and limitations, and advanced fine-tuning techniques for LLMs, proving essential for harnessing their potential to deliver precise and contextually relevant textual responses across diverse applications.
#
# TOPICS:
#  ['Prompt Engineering', 'Natural Language Processing', 'Generative AI']
#
# Q&A:
#  Q: What is prompt engineering?
# A: Prompt engineering is a specialized field within natural language processing that focuses on building models that can generate high quality text outputs.
# Q: Why is prompt engineering important?
# A: It allows us to generate text outputs that are more accurate, coherent, and contextually appropriate than traditional rule-based or keyword-based approaches.
# Q: How are prompt engineering models typically based?
# A: These models are basically based on pre-trained large language models such as OpenAI GPT, Google Bard, or Hugging Face Transformers.
# Q: When is prompt engineering especially important?
# A: It is especially important for applications such as chatbots, language translation, and content generation where output quality impacts user experience.
# Q: Who might struggle with prompt engineering models?
# A: Prompt engineering models may struggle with complex and ambiguous prompts, or generate biased and inaccurate outputs due to underlying data or architecture.
#
# KEY CONCEPTS:
#  Chatbots, Virtual Assistants, Prompt Engineering, Natural Language Processing (NLP), Large Language Models (LLMs), OpenAI GPT, Google Bard, Hugging Face Transformers, Fine-tuning, Text Outputs, Prompt Analysis, Model Architecture
# Saved row 27 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 28: Q-learning - Explained!
# ================================================================================
#
# SUMMARY:
#  Q-learning is a prominent value-based reinforcement learning algorithm enabling agents to learn an optimal policy by maximizing a numerical reward signal. It iteratively learns and updates state-action value functions, or Q-values, which quantify the desirability of taking specific actions in given states, typically stored in a Q-table. The learning process utilizes the Bellman equation and is driven by the temporal difference (TD) error, measuring the discrepancy between an observed Q-value (immediate reward plus discounted maximum future Q-value) and its current expected value. Q-values are updated using the rule: `New Q = Expected Q + alpha * TD error`, where `alpha` is the learning rate. This iterative refinement, occurring over multiple episodes, allows agents to discover optimal actions. Q-learning is an off-policy algorithm, distinguishing between the behavior policy used for exploration and the target policy derived from the learned optimal Q-values, ultimately enabling effective optimal policy learning.
#
# TOPICS:
#  ['Reinforcement Learning']
#
# Q&A:
#  Q: What is the primary objective of reinforcement learning?
# A: Reinforcement learning is learning what to do that is how to map situations to actions so as to maximize a numerical reward signal.
# Q: How do value-based methods determine an optimal policy in reinforcement learning?
# A: Value based methods determine a value function that quantifies total reward, then use it to determine the optimal policy.
# Q: What is a 'state' in the context of reinforcement learning?
# A: A state is a snapshot of the environment.
# Q: Why is Q-learning interested in learning the state-action value function?
# A: For Q learning, we are interested in learning the state action value function because it's a function, easily thought of as a table.
# Q: How is an agent's behavior policy defined during initial exploration in Q-learning?
# A: The actions that an agent takes is simply based on random chance, known as the behavior policy.
#
# KEY CONCEPTS:
#  Q-learning, Reinforcement learning, Machine learning paradigms, Supervised learning, Unsupervised learning, Value-based methods, Policy-based methods, Optimal policy, Agent, State-action value function, Bellman equation, Discount factor
# Saved row 28 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# ================================================================================
# PROCESSING ROW 29: Training Your Logistic Classifier
# ================================================================================
#
# SUMMARY:
#  A logistic classifier operates as a linear model, producing predictions through a linear transformation involving the multiplication of input data (X) by a weight matrix (W) and the addition of a bias term (b). The core machine learning objective is to train the model by identifying optimal values for W and b that yield accurate predictions. For classification scenarios where each input is assigned a single label, the raw prediction scores, commonly referred to as logits, are subsequently transformed into probabilities. This transformation is achieved using the softmax function (S), which converts any set of scores into a valid probability distribution that sums to one, aiming for the correct class's probability to approach unity. This outlines the fundamental mechanism of a logistic classifier, from its linear processing to its probabilistic output.
#
# TOPICS:
#  ['Machine Learning', 'Statistics']
#
# Q&A:
#  Q: What is a logistic classifier?
# A: A logistic classifier is what's called the linear classifier. It takes the input and applies a linear function to them to generate its predictions.
# Q: How does a linear function generate predictions in a logistic classifier?
# A: It takes all inputs as a big vector and multiplies them with a matrix to generate predictions, one per output class.
# Q: What is the purpose of training a logistic classifier model?
# A: Training means trying to find the values for the weights and bias, which are good at performing those predictions.
# Q: How are scores turned into probabilities in a logistic classifier?
# A: The way to turn scores into probabilities is to use a softmax function.
# Q: What are scores in the context of logistic regression also called?
# A: Scores in the context of logistic regression are often also called logits.
#
# KEY CONCEPTS:
#  Logistic Classifier, Linear Classifier, Linear Function, Matrix Multiply, Weights, Bias, Machine Learning, Model, Predictions, Classification, Probabilities, Softmax Function, Logits
# Saved row 29 → /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# DONE. Final file saved: /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
#
# Role-based generation pipeline completed (NO evaluation).

# %%
#####################################################################
# 1. IMPORTS
#####################################################################
import os, re, json, warnings
import pandas as pd
import numpy as np

from rouge_score import rouge_scorer
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from bert_score import score as bert_score

from sklearn.metrics import precision_recall_fscore_support


#####################################################################
# 2. SUPPRESS WARNINGS (BERTScore spam)
#####################################################################
warnings.filterwarnings("ignore")
import logging
logging.getLogger("transformers").setLevel(logging.ERROR)
logging.getLogger("absl").setLevel(logging.ERROR)


#####################################################################
# 3. PATHS (EDIT THESE)
#####################################################################
INPUT_FILE = "/content/drive/MyDrive/Final Thesis Code/Input/clean_input_30.xlsx"
OUTPUT_FILE = "/content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx"
FINAL_EVAL_JSON = "/content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/evaluation_final.json"

print("Loaded input:", INPUT_FILE)
print("Loaded model output:", OUTPUT_FILE)


#####################################################################
# 4. GOLD TOPIC EXTRACTION (KEYWORD-BASED — FINAL VERSION)
#####################################################################
def gold_topics_from_ref_summary(ref_sum: str):
    text = (ref_sum or "").lower()
    matched = []

    rules = [
        ("Natural Language Processing", [
            "nlp", "bert", "transformer", "language model", "token",
            "text processing", "semantic", "embedding"
        ]),
        ("Artificial Intelligence", [
            "artificial intelligence", "ai system", "symbolic ai",
            "reasoning", "planning", "search"
        ]),
        ("Prompt Engineering", [
            "prompt", "few-shot", "zero-shot", "instruction",
            "cot", "chain-of-thought", "in-context learning"
        ]),
        ("Machine Learning", [
            "machine learning", "supervised", "unsupervised", "regression",
            "classification", "clustering", "features"
        ]),
        ("Deep Learning", [
            "deep learning", "neural network", "cnn", "rnn",
            "lstm", "gan", "transformer model", "backpropagation"
        ]),
        ("Reinforcement Learning", [
            "reinforcement", "policy gradient", "q-learning",
            "reward", "actor-critic", "rlhf"
        ]),
        ("Generative AI", [
            "genai", "text generation", "image generation",
            "diffusion", "sampling", "generation model", "llm"
        ]),
        ("Data Science", [
            "data science", "visualization", "feature", "pandas",
            "analysis", "data preprocessing", "eda"
        ]),
        ("Time Series", [
            "time series", "forecasting", "temporal", "trend",
            "seasonality", "arima", "prophet", "lag"
        ]),
        ("Statistics", [
            "statistics", "probability", "distribution", "variance",
            "hypothesis", "confidence interval", "p-value"
        ]),
        ("LangChain", [
            "langchain", "chain", "memory", "retriever",
            "agent executor", "llmchain", "prompt template"
        ]),
        ("Langraph", [
            "langraph", "workflow", "graph", "multi-agent orchestration",
            "node", "edge", "state graph"
        ]),
        ("Python Programming", [
            "python", "numpy", "matplotlib", "function",
            "loop", "list comprehension", "script"
        ]),
        ("Mlops", [
            "mlops", "deployment", "monitoring", "pipeline",
            "model registry", "cicd", "serving"
        ]),
        ("Agentic AI", [
            "agentic", "tool calling", "multi-agent",
            "planner", "agent", "reasoning agent", "autonomous"
        ])
    ]

    for label, keywords in rules:
        if any(kw in text for kw in keywords):
            matched.append(label)

    return matched or ["Other"]


#####################################################################
# 5. TOKENIZER FOR QA & CONCEPTS
#####################################################################
STOPWORDS = set([
    "the","a","an","in","on","for","to","and","or","of","with","as",
    "by","at","from","that","this","is","are","was","were","be","been",
    "it","its","into","about","over","under","between","across",
    "through","their","they","you","your","we","our"
])

def tokenize(text: str):
    return [
        t for t in re.findall(r"[A-Za-z][A-Za-z0-9\-_\’']+", text.lower())
        if t not in STOPWORDS
    ]


#####################################################################
# 6. FINAL EVALUATION FUNCTION  (FULL AND CORRECT)
#####################################################################
def evaluate(df_out: pd.DataFrame, df_ref: pd.DataFrame):

    rouge = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    smooth = SmoothingFunction().method1

    sum_r, sum_b, sum_bert = [], [], []
    overlap_acc_list, jaccard_list, micro_f1_list = [], [], []
    macro_f1_list, weighted_f1_list = [], []
    qa_bleu, qa_div, qa_ans = [], [], []
    kc_p, kc_r, kc_f = [], [], []

    VALID_TOPICS = [
        "Natural Language Processing", "Artificial Intelligence", "Prompt Engineering",
        "Machine Learning", "Deep Learning", "Reinforcement Learning", "Generative AI",
        "Data Science", "Time Series", "Statistics", "LangChain", "Langraph",
        "Python Programming", "Mlops", "Agentic AI", "Other"
    ]

    # for macro/weighted F1
    all_true, all_pred = [], []

    for _, row in df_out.iterrows():
        idx = int(row["row_index"])
        ref_summary = df_ref.loc[idx, "Reference Summary"] or ""

        # -------------------- Summarisation --------------------
        gen_sum = row["summary"] or ""
        r = rouge.score(ref_summary, gen_sum)['rougeL'].fmeasure
        b = sentence_bleu([ref_summary.split()], gen_sum.split(), smoothing_function=smooth)

        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            P, R, F1 = bert_score([gen_sum], [ref_summary], lang='en', verbose=False)

        sum_r.append(r)
        sum_b.append(b)
        sum_bert.append(float(F1.mean()))

        # -------------------- Topic Classification --------------------
        gold = gold_topics_from_ref_summary(ref_summary)
        pred = [x.strip() for x in (row["topic_classification"] or "").split(",") if x.strip()]

        set_pred = set(pred)
        set_gold = set(gold)

        # Overlap Accuracy (your metric)
        overlap_acc = 1.0 if len(set_pred & set_gold) > 0 else 0.0

        # Jaccard
        inter = len(set_pred & set_gold)
        union = len(set_pred | set_gold)
        jaccard = inter / union if union > 0 else 0.0

        # Micro-F1
        tp = inter
        fp = len([p for p in pred if p not in gold])
        fn = len([g for g in gold if g not in pred])

        prec = tp / (tp + fp) if (tp + fp) else 0.0
        rec  = tp / (tp + fn) if (tp + fn) else 0.0
        micro_f1 = (2 * prec * rec / (prec + rec)) if (prec + rec) else 0.0

        overlap_acc_list.append(overlap_acc)
        jaccard_list.append(jaccard)
        micro_f1_list.append(micro_f1)

        # Macro/Weighted F1 prep
        true_bin = [1 if t in gold else 0 for t in VALID_TOPICS]
        pred_bin = [1 if t in pred else 0 for t in VALID_TOPICS]

        all_true.append(true_bin)
        all_pred.append(pred_bin)

        # -------------------- Q&A --------------------
        qa_text = row["Q_and_A"] or ""
        qs = [l[2:].strip() for l in qa_text.splitlines() if l.lower().startswith("q:")]

        gold_qs = [
            "What is the main topic discussed in the video?",
            "Why is this topic important?",
            "How is the core concept explained?",
            "What example is mentioned in the content?",
            "What is the key conclusion of the video?"
        ]

        if qs:
            bleu_vals = [
                sentence_bleu([g.split()], q.split(), smoothing_function=smooth)
                for g in gold_qs for q in qs
            ]
            qa_bleu.append(np.mean(bleu_vals))
        else:
            qa_bleu.append(0.0)

        toks = [t for q in qs for t in q.split()]
        qa_div.append(len(set(toks)) / len(toks) if toks else 0.0)

        ref_tokens = set(tokenize(ref_summary))
        ans_count = sum(
            1 for q in qs
            if len(set(tokenize(q)) & ref_tokens) / max(1, len(tokenize(q))) >= 0.3
        )
        qa_ans.append(ans_count / len(qs) if qs else 0.0)

        # -------------------- Key Concepts --------------------
        kc_text = str(row.get("key_concepts", "") or "")
        pred_concepts = [c.strip().lower() for c in kc_text.split(",") if c.strip()]

        ref_concepts = tokenize(ref_summary)
        ref_top = ref_concepts[:25]

        tp_kc = len([p for p in pred_concepts[:10] if any(p in r or r in p for r in ref_top)])

        p_val = tp_kc / 10
        r_val = tp_kc / len(ref_top) if ref_top else 0
        f1_val = (2*p_val*r_val/(p_val+r_val)) if (p_val+r_val) else 0

        kc_p.append(p_val)
        kc_r.append(r_val)
        kc_f.append(f1_val)

    # Compute macro/weighted F1
    all_true = np.array(all_true)
    all_pred = np.array(all_pred)

    macro_f1 = precision_recall_fscore_support(all_true, all_pred, average="macro", zero_division=0)[2]
    weighted_f1 = precision_recall_fscore_support(all_true, all_pred, average="weighted", zero_division=0)[2]

    return {
        "Summarisation": {
            "ROUGE-L F1": float(np.mean(sum_r)),
            "BLEU": float(np.mean(sum_b)),
            "BERTScore F1": float(np.mean(sum_bert))
        },
        "Topic Classification": {
            "Overlap Accuracy": float(np.mean(overlap_acc_list)),
            "Jaccard Index": float(np.mean(jaccard_list)),
            "Micro F1": float(np.mean(micro_f1_list)),
            "Macro F1": float(macro_f1),
            "Weighted F1": float(weighted_f1)
        },
        "Q&A Generation": {
            "BLEU": float(np.mean(qa_bleu)),
            "Diversity": float(np.mean(qa_div)),
            "Answerability": float(np.mean(qa_ans))
        },
        "Key Concept Extraction": {
            "Precision@10": float(np.mean(kc_p)),
            "Recall@10": float(np.mean(kc_r)),
            "F1@10": float(np.mean(kc_f))
        }
    }


#####################################################################
# 7. RUN EVALUATION
#####################################################################
df_ref = pd.read_excel(INPUT_FILE)
df_out = pd.read_excel(OUTPUT_FILE)

eval_summary = evaluate(df_out, df_ref)

print("\n==================== FINAL EVALUATION METRICS ====================")
for task, vals in eval_summary.items():
    print(f"\n{task}:")
    for metric, value in vals.items():
        print(f"  - {metric}: {value:.4f}")

with open(FINAL_EVAL_JSON, "w") as f:
    json.dump(eval_summary, f, indent=2)

print("\nSaved corrected evaluation JSON to:", FINAL_EVAL_JSON)
# Out:
# Loaded input: /content/drive/MyDrive/Final Thesis Code/Input/clean_input_30.xlsx
# Loaded model output: /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/gemini-2.5-flash_role_full_output.xlsx
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# ==================== FINAL EVALUATION METRICS ====================
#
# Summarisation:
#   - ROUGE-L F1: 0.3509
#   - BLEU: 0.0987
#   - BERTScore F1: 0.8965
#
# Topic Classification:
#   - Overlap Accuracy: 0.9333
#   - Jaccard Index: 0.3877
#   - Micro F1: 0.5204
#   - Macro F1: 0.4828
#   - Weighted F1: 0.5006
#
# Q&A Generation:
#   - BLEU: 0.0265
#   - Diversity: 0.7351
#   - Answerability: 0.7800
#
# Key Concept Extraction:
#   - Precision@10: 0.5467
#   - Recall@10: 0.2187
#   - F1@10: 0.3124
#
# Saved corrected evaluation JSON to: /content/drive/MyDrive/Final Thesis Code/Output/Role Prompting/gemini-2.5-flash/evaluation_final.json
